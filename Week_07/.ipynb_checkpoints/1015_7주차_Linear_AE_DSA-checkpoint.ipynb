# %% [markdown]
# # 7주차 실습_1

# %% [markdown]
# #### Linear AE DSA
# normal : lyingBack, lyingRigh
#
# abnormal: sitting
#
# train(noise O, noise X) / test (noise O)
#
# noise train AE 훈련,
# noise x test AE 예측
#
# 1. Linear AE
# 2. Non-linear AE
# 3. Denoising AE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %%
df = pd.read_csv("C:/Project/DeepLearning/Data/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.shape
# Out:
# (9120, 272)

# %%
df['activity'].value_counts()
# Out:
# activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64

# %% [markdown]
# ## Linear AE

# %% [markdown]
# ### 1.DSA데이터에서 lyingRigh, lyingBack(normal), sitting(abnormal)만 남기기

# %%
df_filtered = df[df['activity'].isin(['sitting', 'lyingRigh', 'lyingBack'])]
df_filtered = df_filtered.drop('people', axis=1)
df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729   sitting
# 1  7.032302e-07     0.000839      0.347471   sitting
# 2  6.268222e-07     0.000792      0.045579   sitting
# 3  8.011245e-07     0.000895      0.240690   sitting
# 4  6.853423e-07     0.000828      0.258429   sitting
#
# [5 rows x 271 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])

df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729         2
# 1  7.032302e-07     0.000839      0.347471         2
# 2  6.268222e-07     0.000792      0.045579         2
# 3  8.011245e-07     0.000895      0.240690         2
# 4  6.853423e-07     0.000828      0.258429         2
#
# [5 rows x 271 columns]

# %%
# StandardScaler 유/무

from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 열 이름의 접두사/접미사를 사용하여 필터링
prefixes = ['T_', 'RA_', 'LA_', 'RL_', 'LL_']  # 원하는 접두사 리스
columns_to_scale = df_filtered.columns[df_filtered.columns.str.startswith(tuple(prefixes))]

# 선택한 열을 스케일링
df_filtered[columns_to_scale] = scaler.fit_transform(df_filtered[columns_to_scale])

# 스케일링 후 데이터 확인
df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     1.168376    1.179659    1.134716    0.424899    1.794701    -0.037407
# 1     1.168870    1.182732    1.166896    0.154077    1.031924     0.987842
# 2     1.167436    1.165165    1.166857   -0.022360    0.310479     0.183152
# 3     1.161106    1.169503    1.136238    0.004198    0.442800    -0.408865
# 4     1.155360    1.173822    1.163969   -0.075787   -0.009354     3.640945
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_var  \
# 0     1.064111    1.057739    1.076760   -0.084875  ...    -0.135903
# 1     1.078602    1.065174    1.092044   -0.152909  ...    -0.135459
# 2     1.078626    1.065149    1.097461   -0.166074  ...    -0.136085
# 3     1.084727    1.091232    1.097234   -0.086558  ...    -0.136242
# 4     1.090312    1.076313    1.101215   -0.158700  ...    -0.135700
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0    -0.337940      0.344190      0.054259     0.047582     0.061705
# 1    -0.325089     -0.608202      0.053994     0.047614     0.061085
# 2    -0.343530     -0.295205      0.054349     0.048032     0.062019
# 3    -0.348571      0.024825      0.055501     0.049890     0.063365
# 4    -0.331922     -0.323528      0.056609     0.050528     0.064247
#
#    LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0    -0.137386    -0.365251      0.185769         2
# 1    -0.137190    -0.361128      0.826319         2
# 2    -0.137782    -0.373792      0.204012         2
# 3    -0.136432    -0.345871      0.606205         2
# 4    -0.137329    -0.364029      0.642770         2
#
# [5 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# activity
# 2    480
# 0    480
# 1    480
# Name: count, dtype: int64

# %% [markdown]
# #### label
#
# 0: lyingBack (normal)
#
# 1: lyingRigh (normal)
#
# 2: sitting (abnormal)
#
# 레이블을 두개로 줄여서 해보면,
#
# 0: lyingBack, lyingRigh (normal)
#
# 1: sitting (abnormal)

# %%
# activity가 0 또는 1인 경우 모두 0으로 통합
df_filtered.loc[df_filtered['activity'].isin([0, 1]), 'activity'] = 0
df_filtered.loc[df_filtered['activity'].isin([2]), 'activity'] = 1

# %%
df_filtered['activity'].value_counts()
# Out:
# activity
# 0    960
# 1    480
# Name: count, dtype: int64

# %%
LABELS = ["Normal", "Abnormal"]

# %%
# normal = df_filtered[(df_filtered.activity == 0)

normal = df_filtered[(df_filtered.activity == 0)]

# activity가 1인 데이터를 선택
abnormal = df_filtered[df_filtered.activity == 1]

# normal 데이터프레임의 모양 확인
normal.shape
# Out:
# (960, 271)

# %%
abnormal.shape
# Out:
# (480, 271)

# %% [markdown]
# ### 2. 두 activity를 섞어서 train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df_filtered, test_size=0.2, random_state=20)

X_train.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 251      0.960117    0.950232    0.962964   -0.098045   -0.179856
# 1014    -1.289385   -1.294578   -1.283105   -0.102654   -0.219978
# 1123    -1.050587   -1.060132   -1.037664   -0.126880   -0.482291
# 255      0.961103    0.951691    0.964408   -0.093102   -0.138963
# 1739    -0.488581   -0.499825   -0.478488   -0.125652   -0.465710
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 251     -1.311638     0.668400    0.650195    0.685310   -0.171214  ...
# 1014    -0.036127     0.626056    0.610749    0.636580   -0.148761  ...
# 1123     0.238646     0.814733    0.806428    0.822114   -0.151350  ...
# 255     -0.458261     0.671522    0.657670    0.683377   -0.158924  ...
# 1739    -0.395609    -1.664104   -1.666665   -1.668773   -0.146667  ...
#
#       LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 251     -0.136614    -0.361264     -0.212728      0.671552     0.665244
# 1014    -0.136716    -0.364954      0.553317     -0.780726    -0.788678
# 1123    -0.135879    -0.337213      0.206020      1.864770     1.858942
# 255     -0.136523    -0.358030      0.138525      0.671246     0.665173
# 1739    -0.136136    -0.345153     -0.068034     -0.942195    -0.951050
#
#       LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 251      0.679390    -0.138551    -0.391492      0.620309         1
# 1014    -0.772968    -0.138579    -0.392168      0.374744         0
# 1123     1.872137    -0.139361    -0.412038     -0.112684         0
# 255      0.678712    -0.137562    -0.368999      0.154338         1
# 1739    -0.933048    -0.139353    -0.411825     -0.048028         0
#
# [5 rows x 271 columns]

# %% [markdown]
# ### 3. train 데이터를 train valid split

# %%
X_train, X_valid = train_test_split(X_train, test_size=0.2, random_state=21)

X_valid.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 1463     0.074978    0.064277    0.080004   -0.112857   -0.317501
# 1013    -1.283197   -1.288781   -1.286032   -0.076998   -0.017845
# 1343    -1.267366   -1.259015   -1.269132   -0.034206    0.246829
# 1215    -1.141538   -1.137250   -1.142655   -0.039372    0.218006
# 1412    -0.715663   -0.717520   -0.707839   -0.078039   -0.025210
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 1463    -0.967199    -1.129255   -1.129524   -1.126370   -0.121108  ...
# 1013    -0.320359     0.629951    0.618021    0.632874   -0.131185  ...
# 1343     1.258852     1.094827    1.079567    1.104364   -0.130006  ...
# 1215     1.087446     0.653626    0.644595    0.662755   -0.149995  ...
# 1412     0.215139     0.221423    0.205393    0.223036   -0.148497  ...
#
#       LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 1463    -0.136109    -0.344287      0.463380     -0.510145    -0.517832
# 1013    -0.136482    -0.356595     -0.018946     -0.777070    -0.784715
# 1343    -0.136271    -0.349524     -0.165663     -0.058851    -0.065814
# 1215    -0.136454    -0.355631      0.149405      1.281949     1.276384
# 1412     0.026986     0.729519      0.341806     -0.980644    -0.950657
#
#       LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 1463    -0.501701    -0.138931    -0.400835      0.654445         0
# 1013    -0.770687    -0.135333    -0.325299     -0.864522         0
# 1343    -0.051548    -0.138871    -0.399335      0.454027         0
# 1215     1.289283    -0.138590    -0.392434      0.677379         0
# 1412    -1.014541     0.321576     1.504825     -0.240988         0
#
# [5 rows x 271 columns]

# %% [markdown]
# ### 4. train/valid에서 sitting 데이터 삭제 (abnormal 삭제)

# %%
# normal feature만 가지는 X_train, X_valid
X_train = X_train[X_train.activity == 0]
X_valid = X_valid[X_valid.activity == 0]

y_train = X_train['activity']
y_valid = X_valid['activity']

X_train = X_train.drop(['activity'], axis=1)
X_valid = X_valid.drop(['activity'], axis=1)

X_train.head()
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 1451     0.069725    0.058285    0.076921   -0.110039   -0.289168
# 1578     0.470717    0.506048    0.466559    0.026734    0.546059
# 1442     0.075318    0.089995    0.053659    0.275290    1.403800
# 1168    -0.963102   -0.971187   -0.973186   -0.098344   -0.182391
# 1724    -0.499824   -0.511663   -0.486076   -0.132379   -0.564745
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 1451    -0.446480    -1.154503   -1.151903   -1.154538   -0.110366  ...
# 1578     1.946354    -1.385382   -1.356066   -1.406768   -0.057302  ...
# 1442    -0.363090    -1.159898   -1.141014   -1.175400    0.046004  ...
# 1168    -1.987899     1.243708    1.225480    1.262288   -0.167385  ...
# 1724    -0.028880    -1.657633   -1.657879   -1.656150   -0.155627  ...
#
#       LL_ymag_min  LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 1451     0.572880    -0.131675    -0.241624     -0.455559     -0.511883
# 1578     1.178608    -0.033134     0.483688      2.367019     -0.796812
# 1442     0.560310    -0.136053    -0.342553     -0.220522     -0.524876
# 1168     0.462689    -0.135913    -0.338247      0.168657     -0.420393
# 1724    -1.336499    -0.136398    -0.353727     -0.564245     -0.940069
#
#       LL_zmag_max  LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 1451    -0.519563    -0.504695    -0.137683    -0.371638     -0.138964
# 1578    -0.778377    -0.798831     0.264234     1.371326      2.664065
# 1442    -0.531007    -0.516798    -0.136154    -0.340507      0.747437
# 1168    -0.426246    -0.412116    -0.136015    -0.337859      0.732760
# 1724    -0.948800    -0.932674    -0.138469    -0.389538     -0.604033
#
# [5 rows x 270 columns]

# %%
y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

X_test
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 1107    -1.040375   -1.047020   -1.030287   -0.118628   -0.379731
# 1383    -0.724460   -0.735943   -0.720270   -0.106926   -0.259182
# 1231    -1.133643   -1.129993   -1.136820    0.029895    0.559990
# 420      1.079787    1.068418    1.088934   -0.118826   -0.381992
# 321      1.221938    1.239111    1.220778   -0.013994    0.353587
# ...           ...         ...         ...         ...         ...
# 1862     0.116330    0.102329    0.129748   -0.134145   -0.595048
# 244      0.954934    0.961905    0.964369   -0.104913   -0.240452
# 280      0.978018    0.970640    0.983357   -0.088783   -0.104820
# 1591     0.445736    0.447918    0.447473   -0.089736   -0.112235
# 287      0.971892    0.961885    0.974673   -0.099009   -0.188071
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 1107     0.631063     0.810056    0.806586    0.814822   -0.129645  ...
# 1383    -1.318774     0.219846    0.210174    0.230997   -0.137811  ...
# 1231     0.273743     0.664786    0.655096    0.681054   -0.165032  ...
# 420     -0.633499     0.622834    0.612179    0.633383   -0.152408  ...
# 321      0.962990     0.680268    0.675172    0.689689   -0.127037  ...
# ...           ...          ...         ...         ...         ...  ...
# 1862    -0.014322    -1.562432   -1.577475   -1.545744   -0.183326  ...
# 244      1.984792     0.660219    0.661242    0.677754   -0.139045  ...
# 280     -0.427770     0.687774    0.674158    0.702022   -0.160340  ...
# 1591    -0.271647    -1.390316   -1.378895   -1.388753   -0.130233  ...
# 287     -1.437633     0.688979    0.672318    0.705731   -0.170658  ...
#
#       LL_ymag_min  LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 1107    -0.286877    -0.135286    -0.320367      0.178222      1.858389
# 1383     0.040398     0.108258     0.998474      1.750317     -0.972906
# 1231    -0.015283    -0.135943    -0.339150      0.415904      1.288468
# 420     -0.673074     0.162449     1.153468     -0.277774      0.989807
# 321      0.895017    -0.136211    -0.347551     -0.032182      0.301799
# ...           ...          ...          ...           ...           ...
# 1862    -2.036574     0.204367     1.263969      0.849630     -0.578911
# 244      0.966877    -0.136826    -0.369113     -0.382373      0.668771
# 280      0.964678    -0.136948    -0.373876      0.442612      0.672615
# 1591     1.189816    -0.131013    -0.229797     -0.304870     -0.790327
# 287      0.964774    -0.136377    -0.353027      0.378905      0.672437
#
#       LL_zmag_max  LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 1107     1.854068     1.865649    -0.139095    -0.405021      0.246336
# 1383    -0.948497    -1.023381     0.404327     1.683691     -3.517947
# 1231     1.283490     1.295824    -0.137910    -0.376654      0.119500
# 420      1.033263     0.968285     0.264218     1.371286      1.255549
# 321      0.294404     0.309987    -0.138682    -0.394669     -0.343645
# ...           ...          ...          ...          ...           ...
# 1862    -0.543450    -0.602835     0.457267     1.791078      0.966700
# 244      0.663548     0.676252    -0.138020    -0.379108      0.846766
# 280      0.666547     0.680495    -0.137891    -0.376223      0.587936
# 1591    -0.795837    -0.785392    -0.120253    -0.128255     -0.344186
# 287      0.666422     0.680227    -0.138803    -0.397650      0.105407
#
# [288 rows x 270 columns]

# %%
# X_train과 X_test를 넘파이 배열로 변환
X_train = X_train.values
X_test = X_test.values
X_valid = X_valid.values

# %%
X_train.shape
# Out:
# (614, 270)

# %%
X_valid.shape
# Out:
# (156, 270)

# %% [markdown]
# ### 4. AE로 normal 정보만 가진 Train 데이터로 모델 학습 (Valid 데이터로 검증)

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 16  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 270)]             0
#
#  dense_12 (Dense)            (None, 16)                4336
#
#  dense_13 (Dense)            (None, 8)                 136
#
#  dense_14 (Dense)            (None, 8)                 72
#
#  dense_15 (Dense)            (None, 270)               2430
#
# =================================================================
# Total params: 6974 (27.24 KB)
# Trainable params: 6974 (27.24 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 학습
history = autoencoder.fit(X_train, X_train, epochs=100, batch_size=256, shuffle=True, validation_data=(X_valid, X_valid))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s 99ms/step - loss: 1.2530 - val_loss: 1.2742
# Epoch 2/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2493 - val_loss: 1.2711
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2454 - val_loss: 1.2682
# Epoch 4/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2418 - val_loss: 1.2650
# Epoch 5/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2379 - val_loss: 1.2614
# Epoch 6/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2332 - val_loss: 1.2569
# Epoch 7/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2278 - val_loss: 1.2515
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.2213 - val_loss: 1.2450
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.2133 - val_loss: 1.2367
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2039 - val_loss: 1.2265
# Epoch 11/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1927 - val_loss: 1.2144
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1796 - val_loss: 1.2009
# Epoch 13/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1644 - val_loss: 1.1858
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1475 - val_loss: 1.1688
# Epoch 15/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1289 - val_loss: 1.1503
# Epoch 16/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1091 - val_loss: 1.1313
# Epoch 17/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0888 - val_loss: 1.1122
# Epoch 18/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0688 - val_loss: 1.0932
# Epoch 19/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0492 - val_loss: 1.0746
# Epoch 20/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0305 - val_loss: 1.0569
# Epoch 21/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0131 - val_loss: 1.0410
# Epoch 22/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9973 - val_loss: 1.0267
# Epoch 23/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9831 - val_loss: 1.0135
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9706 - val_loss: 1.0016
# Epoch 25/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9595 - val_loss: 0.9915
# Epoch 26/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9498 - val_loss: 0.9831
# Epoch 27/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9416 - val_loss: 0.9761
# Epoch 28/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9343 - val_loss: 0.9695
# Epoch 29/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9278 - val_loss: 0.9640
# Epoch 30/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9221 - val_loss: 0.9592
# Epoch 31/100
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9172 - val_loss: 0.9548
# Epoch 32/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9128 - val_loss: 0.9509
# Epoch 33/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9089 - val_loss: 0.9476
# Epoch 34/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9055 - val_loss: 0.9447
# Epoch 35/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9024 - val_loss: 0.9420
# Epoch 36/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8998 - val_loss: 0.9396
# Epoch 37/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8973 - val_loss: 0.9373
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8953 - val_loss: 0.9352
# Epoch 39/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8932 - val_loss: 0.9329
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8915 - val_loss: 0.9304
# Epoch 41/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8898 - val_loss: 0.9281
# Epoch 42/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8883 - val_loss: 0.9259
# Epoch 43/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8868 - val_loss: 0.9239
# Epoch 44/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8855 - val_loss: 0.9221
# Epoch 45/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8843 - val_loss: 0.9206
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8832 - val_loss: 0.9192
# Epoch 47/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8820 - val_loss: 0.9178
# Epoch 48/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8809 - val_loss: 0.9165
# Epoch 49/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8798 - val_loss: 0.9152
# Epoch 50/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8787 - val_loss: 0.9139
# Epoch 51/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8777 - val_loss: 0.9126
# Epoch 52/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8766 - val_loss: 0.9114
# Epoch 53/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8757 - val_loss: 0.9102
# Epoch 54/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8748 - val_loss: 0.9091
# Epoch 55/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8740 - val_loss: 0.9080
# Epoch 56/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8733 - val_loss: 0.9069
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8726 - val_loss: 0.9059
# Epoch 58/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8719 - val_loss: 0.9050
# Epoch 59/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8711 - val_loss: 0.9041
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8705 - val_loss: 0.9032
# Epoch 61/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8698 - val_loss: 0.9023
# Epoch 62/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8691 - val_loss: 0.9014
# Epoch 63/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8684 - val_loss: 0.9006
# Epoch 64/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8676 - val_loss: 0.8997
# Epoch 65/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8669 - val_loss: 0.8989
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8661 - val_loss: 0.8980
# Epoch 67/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8654 - val_loss: 0.8972
# Epoch 68/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8646 - val_loss: 0.8963
# Epoch 69/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8639 - val_loss: 0.8953
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8632 - val_loss: 0.8944
# Epoch 71/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8624 - val_loss: 0.8935
# Epoch 72/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8617 - val_loss: 0.8925
# Epoch 73/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8610 - val_loss: 0.8916
# Epoch 74/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8602 - val_loss: 0.8908
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8595 - val_loss: 0.8900
# Epoch 76/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8586 - val_loss: 0.8891
# Epoch 77/100
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8578 - val_loss: 0.8881
# Epoch 78/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8570 - val_loss: 0.8870
# Epoch 79/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8562 - val_loss: 0.8861
# Epoch 80/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8555 - val_loss: 0.8853
# Epoch 81/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8548 - val_loss: 0.8846
# Epoch 82/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8541 - val_loss: 0.8840
# Epoch 83/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8534 - val_loss: 0.8834
# Epoch 84/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8527 - val_loss: 0.8827
# Epoch 85/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8520 - val_loss: 0.8821
# Epoch 86/100
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8514 - val_loss: 0.8816
# Epoch 87/100
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8508 - val_loss: 0.8811
# Epoch 88/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8502 - val_loss: 0.8806
# Epoch 89/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8497 - val_loss: 0.8800
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8491 - val_loss: 0.8795
# Epoch 91/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8486 - val_loss: 0.8790
# Epoch 92/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8480 - val_loss: 0.8785
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8475 - val_loss: 0.8781
# Epoch 94/100
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8470 - val_loss: 0.8776
# Epoch 95/100
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8466 - val_loss: 0.8772
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8460 - val_loss: 0.8768
# Epoch 97/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8455 - val_loss: 0.8763
# Epoch 98/100
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8450 - val_loss: 0.8758
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8443 - val_loss: 0.8751
# Epoch 100/100
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8435 - val_loss: 0.8743

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 9/9 [==============================] - 0s 2ms/step
#        reconstruction_error  true_class
# count            288.000000  288.000000
# mean               0.813281    0.340278
# std                2.152424    0.474627
# min                0.166072    0.000000
# 25%                0.323387    0.000000
# 50%                0.451914    0.000000
# 75%                0.591635    1.000000
# max               24.514250    1.000000

# %%
error_df = error_df.reset_index(drop=True)
error_df
# Out:
#      reconstruction_error  true_class
# 0                0.594659           0
# 1                0.393570           0
# 2                0.201136           0
# 3                0.910897           1
# 4                0.571606           1
# ..                    ...         ...
# 283              0.518939           0
# 284              0.524610           1
# 285              0.307085           1
# 286              0.394329           0
# 287              0.264005           1
#
# [288 rows x 2 columns]

# %%
threshold = 0.451914

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Normal" if name == 0 else "Abnormal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.64      0.73       190
#            1       0.53      0.78      0.63        98
#
#     accuracy                           0.69       288
#    macro avg       0.69      0.71      0.68       288
# weighted avg       0.74      0.69      0.70       288
