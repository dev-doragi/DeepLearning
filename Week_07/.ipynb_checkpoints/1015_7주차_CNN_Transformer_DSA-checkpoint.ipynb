# %% [markdown]
# # 7주차 도전과제

# %% [markdown]
# 1. DSA data를 불러와서
# 2. 순환 데이터 변형 (Split Sequence)
# 3. Transformer모델로 Classification
#
# CNN 모델과 합쳐서 Transformer모델 만들기

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import keras
from keras import layers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From C:\Anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Data Load

# %%
df = pd.read_csv("C:/Project/DeepLearning/Data/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %% [markdown]
# ### 순환(시계열) 데이터 변환
#
# `split_sequences` 함수는 주어진 시퀀스를 `n_steps`만큼 잘라서 입력 (`X`)과 출력 (`y`)으로 분리한다.
#
# #### 동작 과정:
# 1. **입력 시퀀스 (`X`)**: `n_steps` 동안의 데이터로 구성된다. 이는 주어진 시퀀스에서 매번 `n_steps` 만큼의 데이터 구간을 추출한다.
# 2. **출력 시퀀스 (`y`)**: `n_steps` 이후의 특정 시점에서 레이블만 가져온다. 여기서는 마지막 시점의 데이터를 출력으로 취하고 있으며, `n_features` 이후의 30개 레이블을 선택한다.
#
# 즉, 이 함수는 주로 시계열 또는 순환 데이터를 학습할 때, 연속적인 데이터를 일정한 길이로 나누어 모델이 학습할 수 있도록 만드는 역할을 한다.

# %%
def split_sequences(sequences, n_steps, n_features):
    X, y = list(), list()
    for i in range(len(sequences)):
        # 시퀀스의 끝점 계산
        end_ix = i + n_steps
        # 데이터 범위를 넘어서면 중단
        if end_ix > len(sequences):
            break
        # 입력 시퀀스는 n_steps 동안의 데이터 (마지막 레이블 제외)
        seq_x = sequences[i:end_ix, :n_features]
        # 출력은 end_ix 시점에서 30개의 레이블만 가져옴
        seq_y = sequences[end_ix-1, n_features:]  # 특정 시점에서 한 번에 30개의 레이블만 가져오기
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
df_filtered = df.drop('people', axis=1)
df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729   sitting
# 1  7.032302e-07     0.000839      0.347471   sitting
# 2  6.268222e-07     0.000792      0.045579   sitting
# 3  8.011245e-07     0.000895      0.240690   sitting
# 4  6.853423e-07     0.000828      0.258429   sitting
#
# [5 rows x 271 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])

df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729        12
# 1  7.032302e-07     0.000839      0.347471        12
# 2  6.268222e-07     0.000792      0.045579        12
# 3  8.011245e-07     0.000895      0.240690        12
# 4  6.853423e-07     0.000828      0.258429        12
#
# [5 rows x 271 columns]

# %% [markdown]
# ## StandardScaler

# %% [markdown]
# 각 피쳐의 값 범위가 매우 다르기 때문에 StandardScaler를 통해 스케일을 좁혀보자.

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 객체 생성
scaler = StandardScaler()

# 열 이름의 접두사/접미사를 사용하여 필터링
prefixes = ['T_', 'RA_', 'LA_', 'RL_', 'LL_']  # 원하는 접두사 리스트
columns_to_scale = df_filtered.columns[df_filtered.columns.str.startswith(tuple(prefixes))]

# 선택한 열을 스케일링
df_filtered[columns_to_scale] = scaler.fit_transform(df_filtered[columns_to_scale])

# 스케일링 후 데이터 확인
df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     0.055870   -0.546828    0.725530   -0.393761   -0.680020    -0.428085
# 1     0.056545   -0.545491    0.754858   -0.393913   -0.689658     0.321260
# 2     0.054587   -0.553129    0.754823   -0.394011   -0.698774    -0.266880
# 3     0.045943   -0.551243    0.726917   -0.393997   -0.697102    -0.699580
# 4     0.038098   -0.549365    0.752191   -0.394041   -0.702816     2.260389
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_var  \
# 0     0.860379   -0.148110    1.180617   -0.523874  ...    -0.763476
# 1     0.886595   -0.141000    1.195850   -0.524238  ...    -0.763471
# 2     0.886639   -0.141024    1.201248   -0.524308  ...    -0.763478
# 3     0.897675   -0.116077    1.201022   -0.523883  ...    -0.763479
# 4     0.907779   -0.130346    1.204990   -0.524269  ...    -0.763474
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0    -1.258551      0.441264     -0.350861    -0.623732    -0.017723
# 1    -1.257727     -0.439297     -0.351291    -0.623682    -0.018691
# 2    -1.258909     -0.149907     -0.350716    -0.623032    -0.017234
# 3    -1.259232      0.145985     -0.348852    -0.620142    -0.015135
# 4    -1.258165     -0.176094     -0.347060    -0.619151    -0.013759
#
#    LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0    -0.400560    -0.913563      0.204309        12
# 1    -0.400558    -0.913325      0.705828        12
# 2    -0.400562    -0.914056      0.218593        12
# 3    -0.400553    -0.912443      0.533490        12
# 4    -0.400559    -0.913492      0.562119        12
#
# [5 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# activity
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: count, dtype: int64

# %%
X=df_filtered.drop(['activity'], axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     0.055870   -0.546828    0.725530   -0.393761   -0.680020    -0.428085
# 1     0.056545   -0.545491    0.754858   -0.393913   -0.689658     0.321260
# 2     0.054587   -0.553129    0.754823   -0.394011   -0.698774    -0.266880
# 3     0.045943   -0.551243    0.726917   -0.393997   -0.697102    -0.699580
# 4     0.038098   -0.549365    0.752191   -0.394041   -0.702816     2.260389
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_min  \
# 0     0.860379   -0.148110    1.180617   -0.523874  ...     0.519750
# 1     0.886595   -0.141000    1.195850   -0.524238  ...     0.519916
# 2     0.886639   -0.141024    1.201248   -0.524308  ...     0.522510
# 3     0.897675   -0.116077    1.201022   -0.523883  ...     0.523062
# 4     0.907779   -0.130346    1.204990   -0.524269  ...     0.521765
#
#    LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  \
# 0    -0.763476    -1.258551      0.441264     -0.350861    -0.623732
# 1    -0.763471    -1.257727     -0.439297     -0.351291    -0.623682
# 2    -0.763478    -1.258909     -0.149907     -0.350716    -0.623032
# 3    -0.763479    -1.259232      0.145985     -0.348852    -0.620142
# 4    -0.763474    -1.258165     -0.176094     -0.347060    -0.619151
#
#    LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 0    -0.017723    -0.400560    -0.913563      0.204309
# 1    -0.018691    -0.400558    -0.913325      0.705828
# 2    -0.017234    -0.400562    -0.914056      0.218593
# 3    -0.015135    -0.400553    -0.912443      0.533490
# 4    -0.013759    -0.400559    -0.913492      0.562119
#
# [5 rows x 270 columns]

# %%
y=df_filtered['activity']
y.value_counts()
# Out:
# activity
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 3482     0.419664   -0.267410    0.857712   -0.390597   -0.599402
# 5048     0.289253   -0.130556    0.213787   -0.261283   -0.001363
# 8682     0.444226    0.915389   -2.387490    0.204361    0.799904
# 85       0.496390   -0.415049    1.058778   -0.394059   -0.705942
# 4265     0.538101   -0.008419    0.135068   -0.261913   -0.003057
# ...           ...         ...         ...         ...         ...
# 4373     0.448697   -0.124381    0.328237   -0.307457   -0.138625
# 7891     0.079846   -0.287456   -0.615208   -0.257268    0.009345
# 4859     0.407423    0.029474    0.181631   -0.247453    0.034875
# 3264     0.077620   -0.529928    0.708385   -0.392884   -0.647255
# 2732    -0.172971    0.018478   -0.640808   -0.046015    0.440333
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 3482     1.766596     0.482579    0.143300    0.265497    0.011474  ...
# 5048    -0.372821     0.436366    0.152278    0.322950   -0.294576  ...
# 8682    -0.827652     0.043703    1.562785   -2.802558    2.130162  ...
# 85      -0.459722    -0.045746   -0.608613    0.669579   -0.523371  ...
# 4265    -0.541621     0.121592    0.302675    0.079200   -0.170676  ...
# ...           ...          ...         ...         ...         ...  ...
# 4373    -0.462540     0.429048    0.118952    0.069884   -0.128048  ...
# 7891    -1.447639     0.592660    0.114140    0.305071   -0.256926  ...
# 4859    -0.042758     0.554886    0.498584    0.363278   -0.156013  ...
# 3264    -1.301710    -0.200471   -0.681803    0.576770   -0.523078  ...
# 2732    -1.366976     0.725592    0.062499    0.824522   -0.431907  ...
#
#       LL_ymag_min  LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# 3482    -1.464914    -0.601034    -0.523085      0.232655      0.164311
# 5048    -0.289184     1.336399     1.410150     -0.814559      0.074818
# 8682     0.241955     0.383108     0.710981     -1.315558     -0.538672
# 85       1.269129    -0.763475    -1.258426      0.286603      1.653274
# 4265    -2.371487     0.405519     0.730228     -0.567322     -0.073746
# ...           ...          ...          ...           ...           ...
# 4373     0.357864     0.096386     0.445775      0.001467      0.274422
# 7891     1.806422    -0.533621    -0.381912      0.502539     -0.212061
# 4859     0.479237     0.124998     0.474054     -1.003366      0.144897
# 3264    -0.962090    -0.469174    -0.265364      0.052740      0.519024
# 2732    -0.964684    -0.281622     0.014920      0.092235      0.981501
#
#       LL_zmag_max  LL_zmag_min  LL_zmag_var  LL_zmag_std  LL_zmag_skew
# 3482     0.185977     0.191275    -0.180076     0.084982     -0.048766
# 5048    -0.022785    -0.026008    -0.196340     0.046971     -1.477950
# 8682     0.228596    -1.480582     1.839287     2.296963     -0.709158
# 85       1.306226     1.911123    -0.400556    -0.912833     -0.056411
# 4265    -0.004433    -0.195205    -0.131990     0.189819     -0.729581
# ...           ...          ...          ...          ...           ...
# 4373     0.274102     0.428105    -0.309710    -0.277118      1.695668
# 7891    -0.170021    -0.120088    -0.231851    -0.041680      0.676274
# 4859     0.166931     0.271166    -0.325120    -0.334718      0.993850
# 3264     0.595645     0.377782     0.188570     0.726753     -0.505567
# 2732     1.128616     0.146976     1.843957     2.300321     -2.080342
#
# [6840 rows x 270 columns]

# %% [markdown]
# ## Build the model

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Multi-Head Attention 레이어 적용 (자기 자신과의 Attention)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
        # 각각 self-attention의 크기, 헤드의 수, 피드포워드 차원, 드롭아웃 비율
    )(inputs, inputs)
    
    # Dropout으로 과적합 방지
    x = layers.Dropout(dropout)(x)
    
    # Layer Normalization으로 학습 안정화
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    
    # Residual Connection: 원래 입력과 Attention 결과를 더함
    # 입력 데이터 inputs과 층을 거친 출력 데이터 x를 더해 다음 입력 데이터로 쓴다. -> 입력 데이터가 층을 건너뛰었다.
    res = x + inputs

    # Feed Forward Part: 1x1 Conv를 사용한 비선형 변환 (차원 증가)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    
    # Dropout으로 다시 과적합 방지
    x = layers.Dropout(dropout)(x)
    
    # 다시 Conv1D로 원래 입력 크기로 복구 (차원 감소), inputs.shape[-1] = 필터 수는 입력 데이터의 마지막 차원 크기와 동일하게 설정
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    
    # Layer Normalization으로 학습 안정화
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    
    # 최종 Residual Connection: Feed Forward 결과와 Attention 결과를 더함
    return x + res

# %%
def build_model(
    input_shape,
    n_outputs,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks, # 해당 파라미터 값을 변경하여 적용한다.
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_outputs, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
# Merge train and test X/y data to apply sequence transformation function
y_train_array = np.array(y_train)
# np.c_ : 배열을 열 방향으로 이어붙인다.
train_set = np.c_[X_train, y_train_array]

y_test_array = np.array(y_test)
test_set = np.c_[X_test, y_test_array]

print(test_set)
# Out:
# [[ 0.06956998 -0.33279226  0.28423533 ...  0.          0.
#    0.        ]
#  [ 0.49655011  0.00562165  0.46909816 ...  0.          1.
#    0.        ]
#  [ 0.08805305 -0.43553441  0.55706541 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.11132853  0.94972965 -0.48450524 ...  0.          0.
#    0.        ]
#  [ 0.15083931 -0.07946817  0.10737598 ...  0.          0.
#    1.        ]
#  [ 0.51992305 -0.01789223  0.25648989 ...  1.          0.
#    0.        ]]

# %%
# Apply sequence transformation using time step of 25 for both train and test data
# All sensing modalities are recorded at a sampling rate of 50 Hz, which is considered sufficient for capturing human activity.

X_train, y_train = split_sequences(train_set, 5, X_test.shape[1])
print(X_train.shape, y_train.shape)

X_test, y_test = split_sequences(test_set, 5, X_test.shape[1])
print(X_test.shape, y_test.shape)
# Out:
# (6836, 5, 270) (6836, 19)
# (2276, 5, 270) (2276, 19)

# %%
n_classes = len(np.unique(y_train))

idx = np.random.permutation(len(X_train))
X_train = X_train[idx]
y_train = y_train[idx]

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

n_classes
# Out:
# 2

# %%
# 각각 스텝 수, feature 수, label 수
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 5 270 19

# %%
input_shape = X_train.shape[1:]
input_shape
# Out:
# (5, 270)

# %%
model = build_model(
    input_shape,
    n_outputs,
    head_size=256,
    num_heads=4,
    ff_dim=128,
    num_transformer_blocks=2,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.5,
)


model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["accuracy"],
)
model.summary()

# callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

model_history=model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=64,
#    callbacks=callbacks,
)

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test, axis=1) # 배열에서 최댓값을 가지는 원소의 인덱스를 반환하는 함수
y_pred_class = np.argmax(y_pred, axis=1)

model.evaluate(X_test, y_test, verbose=1)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 5, 270)]             0         []
#
#  multi_head_attention_2 (Mu  (None, 5, 270)               1109262   ['input_2[0][0]',
#  ltiHeadAttention)                                                   'input_2[0][0]']
#
#  dropout_5 (Dropout)         (None, 5, 270)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  layer_normalization_4 (Lay  (None, 5, 270)               540       ['dropout_5[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_4 (TF  (None, 5, 270)               0         ['layer_normalization_4[0][0]'
#  OpLambda)                                                          , 'input_2[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5, 128)               34688     ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 5, 128)               0         ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5, 270)               34830     ['dropout_6[0][0]']
#
#  layer_normalization_5 (Lay  (None, 5, 270)               540       ['conv1d_5[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_5 (TF  (None, 5, 270)               0         ['layer_normalization_5[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_4[0][0
#                                                                     ]']
#
#  multi_head_attention_3 (Mu  (None, 5, 270)               1109262   ['tf.__operators__.add_5[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 5, 270)               0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  layer_normalization_6 (Lay  (None, 5, 270)               540       ['dropout_7[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_6 (TF  (None, 5, 270)               0         ['layer_normalization_6[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_5[0][0
#                                                                     ]']
#
#  conv1d_6 (Conv1D)           (None, 5, 128)               34688     ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 5, 128)               0         ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5, 270)               34830     ['dropout_8[0][0]']
#
#  layer_normalization_7 (Lay  (None, 5, 270)               540       ['conv1d_7[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 5, 270)               0         ['layer_normalization_7[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_6[0][0
#                                                                     ]']
#
#  global_average_pooling1d_1  (None, 270)                  0         ['tf.__operators__.add_7[0][0]
#   (GlobalAveragePooling1D)                                          ']
#
#  dense_2 (Dense)             (None, 128)                  34688     ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 19)                   2451      ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 2396859 (9.14 MB)
# Trainable params: 2396859 (9.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/50
# 107/107 [==============================] - 17s 98ms/step - loss: 2.9050 - accuracy: 0.1368 - val_loss: 2.4411 - val_accuracy: 0.2263
# Epoch 2/50
# 107/107 [==============================] - 9s 89ms/step - loss: 2.6042 - accuracy: 0.1941 - val_loss: 2.3817 - val_accuracy: 0.2434
# Epoch 3/50
# 107/107 [==============================] - 11s 104ms/step - loss: 2.5465 - accuracy: 0.2067 - val_loss: 2.3422 - val_accuracy: 0.2491
# Epoch 4/50
# 107/107 [==============================] - 17s 157ms/step - loss: 2.4895 - accuracy: 0.2153 - val_loss: 2.3400 - val_accuracy: 0.2509
# Epoch 5/50
# 107/107 [==============================] - 16s 147ms/step - loss: 2.4150 - accuracy: 0.2338 - val_loss: 2.3328 - val_accuracy: 0.2469
# Epoch 6/50
# 107/107 [==============================] - 13s 122ms/step - loss: 2.4136 - accuracy: 0.2327 - val_loss: 2.3052 - val_accuracy: 0.2619
# Epoch 7/50
# 107/107 [==============================] - 12s 114ms/step - loss: 2.3844 - accuracy: 0.2421 - val_loss: 2.2734 - val_accuracy: 0.2583
# Epoch 8/50
# 107/107 [==============================] - 11s 107ms/step - loss: 2.3408 - accuracy: 0.2510 - val_loss: 2.2532 - val_accuracy: 0.2698
# Epoch 9/50
# 107/107 [==============================] - 11s 99ms/step - loss: 2.3280 - accuracy: 0.2463 - val_loss: 2.3155 - val_accuracy: 0.2610
# Epoch 10/50
# 107/107 [==============================] - 10s 96ms/step - loss: 2.3000 - accuracy: 0.2578 - val_loss: 2.2656 - val_accuracy: 0.2667
# Epoch 11/50
# 107/107 [==============================] - 11s 105ms/step - loss: 2.2619 - accuracy: 0.2657 - val_loss: 2.2666 - val_accuracy: 0.2680
# Epoch 12/50
# 107/107 [==============================] - 11s 107ms/step - loss: 2.2479 - accuracy: 0.2626 - val_loss: 2.2519 - val_accuracy: 0.2689
# Epoch 13/50
# 107/107 [==============================] - 13s 122ms/step - loss: 2.2435 - accuracy: 0.2686 - val_loss: 2.2600 - val_accuracy: 0.2636
# Epoch 14/50
# 107/107 [==============================] - 13s 125ms/step - loss: 2.2188 - accuracy: 0.2697 - val_loss: 2.2501 - val_accuracy: 0.2632
# Epoch 15/50
# 107/107 [==============================] - 15s 138ms/step - loss: 2.1817 - accuracy: 0.2790 - val_loss: 2.2265 - val_accuracy: 0.2597
# Epoch 16/50
# 107/107 [==============================] - 16s 146ms/step - loss: 2.1874 - accuracy: 0.2765 - val_loss: 2.3077 - val_accuracy: 0.2544
# Epoch 17/50
# 107/107 [==============================] - 11s 107ms/step - loss: 2.1865 - accuracy: 0.2790 - val_loss: 2.2520 - val_accuracy: 0.2658
# Epoch 18/50
# 107/107 [==============================] - 10s 95ms/step - loss: 2.1542 - accuracy: 0.2820 - val_loss: 2.2162 - val_accuracy: 0.2531
# Epoch 19/50
# 107/107 [==============================] - 9s 87ms/step - loss: 2.1542 - accuracy: 0.2791 - val_loss: 2.2738 - val_accuracy: 0.2535
# Epoch 20/50
# 107/107 [==============================] - 10s 90ms/step - loss: 2.1254 - accuracy: 0.2873 - val_loss: 2.2773 - val_accuracy: 0.2623
# Epoch 21/50
# 107/107 [==============================] - 11s 106ms/step - loss: 2.1174 - accuracy: 0.2895 - val_loss: 2.2757 - val_accuracy: 0.2566
# Epoch 22/50
# 107/107 [==============================] - 12s 111ms/step - loss: 2.0844 - accuracy: 0.3044 - val_loss: 2.2770 - val_accuracy: 0.2518
# Epoch 23/50
# 107/107 [==============================] - 11s 106ms/step - loss: 2.0683 - accuracy: 0.2977 - val_loss: 2.3386 - val_accuracy: 0.2544
# Epoch 24/50
# 107/107 [==============================] - 11s 99ms/step - loss: 2.0530 - accuracy: 0.2994 - val_loss: 2.2944 - val_accuracy: 0.2579
# Epoch 25/50
# 107/107 [==============================] - 10s 93ms/step - loss: 2.0433 - accuracy: 0.3027 - val_loss: 2.2788 - val_accuracy: 0.2570
# Epoch 26/50
# 107/107 [==============================] - 9s 87ms/step - loss: 2.0476 - accuracy: 0.3062 - val_loss: 2.3078 - val_accuracy: 0.2579
# Epoch 27/50
# 107/107 [==============================] - 9s 86ms/step - loss: 2.0401 - accuracy: 0.3008 - val_loss: 2.3494 - val_accuracy: 0.2592
# Epoch 28/50
# 107/107 [==============================] - 10s 96ms/step - loss: 1.9987 - accuracy: 0.3171 - val_loss: 2.3196 - val_accuracy: 0.2654
# Epoch 29/50
# 107/107 [==============================] - 11s 105ms/step - loss: 1.9898 - accuracy: 0.3189 - val_loss: 2.3151 - val_accuracy: 0.2619
# Epoch 30/50
# 107/107 [==============================] - 11s 105ms/step - loss: 1.9975 - accuracy: 0.3122 - val_loss: 2.3423 - val_accuracy: 0.2605
# Epoch 31/50
# 107/107 [==============================] - 11s 104ms/step - loss: 1.9819 - accuracy: 0.3227 - val_loss: 2.3633 - val_accuracy: 0.2465
# Epoch 32/50
# 107/107 [==============================] - 10s 97ms/step - loss: 1.9699 - accuracy: 0.3188 - val_loss: 2.3625 - val_accuracy: 0.2601
# Epoch 33/50
# 107/107 [==============================] - 9s 88ms/step - loss: 1.9638 - accuracy: 0.3195 - val_loss: 2.4020 - val_accuracy: 0.2588
# Epoch 34/50
# 107/107 [==============================] - 9s 85ms/step - loss: 1.9402 - accuracy: 0.3300 - val_loss: 2.4439 - val_accuracy: 0.2610
# Epoch 35/50
# 107/107 [==============================] - 9s 88ms/step - loss: 1.9277 - accuracy: 0.3288 - val_loss: 2.3937 - val_accuracy: 0.2544
# Epoch 36/50
# 107/107 [==============================] - 11s 99ms/step - loss: 1.9321 - accuracy: 0.3315 - val_loss: 2.4407 - val_accuracy: 0.2619
# Epoch 37/50
# 107/107 [==============================] - 11s 103ms/step - loss: 1.9134 - accuracy: 0.3316 - val_loss: 2.4165 - val_accuracy: 0.2575
# Epoch 38/50
# 107/107 [==============================] - 11s 103ms/step - loss: 1.9292 - accuracy: 0.3392 - val_loss: 2.4468 - val_accuracy: 0.2491
# Epoch 39/50
# 107/107 [==============================] - 11s 101ms/step - loss: 1.9226 - accuracy: 0.3351 - val_loss: 2.4223 - val_accuracy: 0.2518
# Epoch 40/50
# 107/107 [==============================] - 10s 95ms/step - loss: 1.8895 - accuracy: 0.3482 - val_loss: 2.4423 - val_accuracy: 0.2562
# Epoch 41/50
# 107/107 [==============================] - 10s 93ms/step - loss: 1.8914 - accuracy: 0.3385 - val_loss: 2.4549 - val_accuracy: 0.2583
# Epoch 42/50
# 107/107 [==============================] - 11s 101ms/step - loss: 1.8836 - accuracy: 0.3403 - val_loss: 2.4424 - val_accuracy: 0.2500
# Epoch 43/50
# 107/107 [==============================] - 11s 104ms/step - loss: 1.8584 - accuracy: 0.3477 - val_loss: 2.4737 - val_accuracy: 0.2535
# Epoch 44/50
# 107/107 [==============================] - 11s 104ms/step - loss: 1.8492 - accuracy: 0.3506 - val_loss: 2.5069 - val_accuracy: 0.2597
# Epoch 45/50
# 107/107 [==============================] - 11s 99ms/step - loss: 1.8386 - accuracy: 0.3523 - val_loss: 2.5113 - val_accuracy: 0.2460
# Epoch 46/50
# 107/107 [==============================] - 10s 93ms/step - loss: 1.8294 - accuracy: 0.3537 - val_loss: 2.4564 - val_accuracy: 0.2500
# Epoch 47/50
# 107/107 [==============================] - 9s 88ms/step - loss: 1.8362 - accuracy: 0.3508 - val_loss: 2.4517 - val_accuracy: 0.2619
# Epoch 48/50
# 107/107 [==============================] - 9s 83ms/step - loss: 1.8313 - accuracy: 0.3542 - val_loss: 2.4378 - val_accuracy: 0.2491
# Epoch 49/50
# 107/107 [==============================] - 9s 89ms/step - loss: 1.8054 - accuracy: 0.3670 - val_loss: 2.4745 - val_accuracy: 0.2566
# Epoch 50/50
# 107/107 [==============================] - 11s 101ms/step - loss: 1.8143 - accuracy: 0.3561 - val_loss: 2.4901 - val_accuracy: 0.2636
# 72/72 [==============================] - 2s 16ms/step
# 72/72 [==============================] - 1s 16ms/step - loss: 2.4901 - accuracy: 0.2636
# [2.4901175498962402, 0.26362037658691406]

# %% [markdown]
# ## Evaluate

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report,confusion_matrix

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
print("\n----------------classification_report-----------------")
print(classification_report(y_test_class, y_pred_class))
print("\n------------------confusion_matrix--------------------")
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
# ----------------classification_report-----------------
#               precision    recall  f1-score   support
#
#            0       0.29      0.33      0.31       118
#            1       0.33      0.29      0.31       124
#            2       0.21      0.23      0.22       119
#            3       0.22      0.25      0.24       118
#            4       0.25      0.33      0.29       126
#            5       0.28      0.19      0.23       130
#            6       0.25      0.25      0.25       130
#            7       0.30      0.29      0.29       126
#            8       0.26      0.30      0.28       120
#            9       0.23      0.12      0.16       127
#           10       0.35      0.35      0.35       113
#           11       0.26      0.37      0.30       122
#           12       0.26      0.31      0.28       127
#           13       0.29      0.25      0.27       112
#           14       0.27      0.13      0.18       113
#           15       0.26      0.27      0.26       116
#           16       0.24      0.31      0.27       118
#           17       0.24      0.19      0.21       111
#           18       0.24      0.23      0.24       106
#
#     accuracy                           0.26      2276
#    macro avg       0.26      0.26      0.26      2276
# weighted avg       0.26      0.26      0.26      2276
#
#
# ------------------confusion_matrix--------------------
# [[39  2  2  3  9  3  6  2  6  2  2  8  7  7  1  5  6  5  3]
#  [ 7 36  5  9  5  2  7  7  3  5  3  6  2  3  5  6  3  4  6]
#  [ 7  3 27  4  8  1  8  2  6  7  5 13  7  3  0  0  4  5  9]
#  [ 8  7  7 30  4  5  8  2  2  3  1  5  9  3  1  9  4  4  6]
#  [ 4  7  6  8 42  6  5  6  3  1  7  5  5  6  0  4  6  2  3]
#  [ 2  4  5  9  9 25  4  9  8  2  4 12  6  2  1  8 13  5  2]
#  [ 5  3  8  5  6  6 33 10 10  1  7  8  6  7  3  8  1  1  2]
#  [ 8  5  8  8  9  3  4 37  6  0  0  5 10  2  4  3  6  0  8]
#  [ 7  2  5  4  4  4  4  8 36  5  4  6  6  3  1  5  8  5  3]
#  [ 9  7  8  6 12  5  7  3  5 15  4  9  8  3  8  5  4  5  4]
#  [ 6  4  2  0  9  1  5  3  4  2 40  2  4  5  4  6  9  4  3]
#  [ 3  2  2  6  3  5  1  0  5  5  8 45  9  3  5  5 10  3  2]
#  [ 6  3  3  7  8  5  9  6 12  1  3  3 39  2  2  6  6  3  3]
#  [ 7  3  8  4  8  4  4  5  6  1  3 11  5 28  3  2  6  2  2]
#  [ 5  1  6  6  8  4  5  5  6  5  7  6  3  9 15  7  7  5  3]
#  [ 4  1  9  6  5  5  8  4  4  3  4  8  6  5  0 31  6  3  4]
#  [ 0  5  2 12  8  2  2  6  9  3  6  5 11  1  0  3 37  3  3]
#  [ 3  7  5  6  5  3  2  6  6  1  4  8  7  2  1  2 14 21  8]
#  [ 5  8  9  4  6  1  8  4  2  2  2  9  2  3  2  3  4  8 24]]
