# %% [markdown]
# # 2주차 Report

# %% [markdown]
# ## 1. Data Load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv("C:/Project/DeepLearning/Data/abalone.csv", index_col=0) # \는 콜백문자 때문에 \\로 사용한다.
df.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.hist(figsize=(15, 10), grid=False, alpha=0.5, color='purple')
# Out:
# array([[<Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diameter'}>,
#         <Axes: title={'center': 'Height'}>],
#        [<Axes: title={'center': 'Whole weight'}>,
#         <Axes: title={'center': 'Shucked weight'}>,
#         <Axes: title={'center': 'Viscera weight'}>],
#        [<Axes: title={'center': 'Shell weight'}>,
#         <Axes: title={'center': 'Rings'}>, <Axes: >]], dtype=object)

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="Rings")
plt.xlabel("Rings")
plt.ylabel("Count")
plt.title("Rings of abalone")
# Out:
# Text(0.5, 1.0, 'Rings of abalone')

# %%
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
import pandas as pd

# 기존 abalone 데이터셋 로드
# 데이터가 abalone.csv 파일에 있다고 가정

# rings=1인 데이터와 rings=29인 데이터 추출
rings_1_data = df[df['Rings'] == 1].copy()
rings_29_data = df[df['Rings'] == 29].copy()

# rings=1인 데이터를 rings=0으로 변경
rings_1_data['Rings'] = 0

# rings=29인 데이터를 rings=28로 변경
rings_29_data['Rings'] = 28

# 기존 데이터에 rings=0과 rings=28 데이터를 추가
df = pd.concat([df, rings_1_data, rings_29_data], ignore_index=True)

# 추가된 데이터 확인
df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 0       2
# 28      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
df_corr = df[[ 'Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']]

#상관 관계 행렬
# 0.3 이상인 경우 상관관계가 있고, 0.7이상이면 아주 높음

df_corr=df_corr.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cbar=False)
plt.show()

# %% [markdown]
# Sex, Rings은 다른 특성들과의 상관관계가 특히 낮다.
#
# Abalone 데이터에 따르면, Rings 값에 1.5를 더하면 전복의 나이가 된다고 한다.

# %%
# Convert RingCount to Age by adding 1.5, accoring to codebook
df['Age'] = df['Rings'] + 1.5
# df.drop('Rings', axis=1, inplace=True)

# %%
#레이블을 숫자로 변환
from sklearn.preprocessing import StandardScaler, LabelEncoder

# LabelEncoder 객체 생성
label = LabelEncoder()

# 문자로 지정된 열의 데이터에 대해 LabelEncoder를 적용하여 변환
df['Sex'] = label.fit_transform(df['Sex'])

df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
# 4177    1   0.075     0.055   0.010        0.0020          0.0010
# 4178    0   0.700     0.585   0.185        1.8075          0.7055
# 4179    1   0.075     0.055   0.010        0.0020          0.0010
# 4180    0   0.700     0.585   0.185        1.8075          0.7055
#
#       Viscera weight  Shell weight  Rings   Age
# 0             0.1010        0.1500     15  16.5
# 1             0.0485        0.0700      7   8.5
# 2             0.1415        0.2100      9  10.5
# 3             0.1140        0.1550     10  11.5
# 4             0.0395        0.0550      7   8.5
# ...              ...           ...    ...   ...
# 4176          0.3765        0.4950     12  13.5
# 4177          0.0005        0.0015      0   1.5
# 4178          0.3215        0.4750     28  29.5
# 4179          0.0005        0.0015      0   1.5
# 4180          0.3215        0.4750     28  29.5
#
# [4181 rows x 10 columns]

# %% [markdown]
# ## 2. Train Test Split

# %%
X=df.drop(['Age', 'Rings'], axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %% [markdown]
# #### y label
#
# No of Classes : 0
#
# 1 -> Rings <= 8
#
# 2 -> Rings > 8 && Rings <= 11
#
# 3 -> Rings > 11

# %%
new_df = df.copy()

# %%
new_df['newRings_1'] = np.where(df['Rings'] <= 8, 1,0)
new_df['newRings_2'] = np.where(((df['Rings'] > 8) & (df['Rings'] <= 10)), 2,0)
new_df['newRings_3'] = np.where(df['Rings'] > 10, 3,0)

new_df['newRings'] = new_df['newRings_1'] + new_df['newRings_2'] + new_df['newRings_3']

# %%
X=df.drop(['Sex', 'Age', 'Rings'], axis=1)

X.head()
# head()는 첫 5행만 출력함.
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight
# 0         0.150
# 1         0.070
# 2         0.210
# 3         0.155
# 4         0.055

# %%
y = new_df['newRings']
y.value_counts().sort_index(ascending=True)
# Out:
# newRings
# 1    1409
# 2    1323
# 3    1449
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[False, False,  True],
#        [ True, False, False],
#        [False,  True, False],
#        ...,
#        [False, False,  True],
#        [ True, False, False],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 2252   0.570     0.460   0.170        1.1000          0.4125          0.2205
# 1742   0.680     0.510   0.200        1.6075          0.7140          0.3390
# 2066   0.540     0.385   0.140        0.7655          0.3265          0.1160
# 3394   0.620     0.480   0.160        1.0765          0.4120          0.2530
# 3437   0.395     0.300   0.090        0.2790          0.1340          0.0490
# ...      ...       ...     ...           ...             ...             ...
# 1033   0.650     0.525   0.185        1.6220          0.6645          0.3225
# 3264   0.655     0.500   0.140        1.1705          0.5405          0.3175
# 1653   0.595     0.450   0.145        0.9590          0.4630          0.2065
# 2607   0.625     0.490   0.165        1.1270          0.4770          0.2365
# 2732   0.410     0.325   0.110        0.3260          0.1325          0.0750
#
#       Shell weight
# 2252        0.3800
# 1742        0.4705
# 2066        0.2365
# 3394        0.3000
# 3437        0.0750
# ...            ...
# 1033        0.4770
# 3264        0.2850
# 1653        0.2535
# 2607        0.3185
# 2732        0.1010
#
# [3135 rows x 7 columns]

# %%
# Scale X
scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

# %%
X_train.shape[1]
# Out:
# 7

# %%
y_test.shape[1]
# Out:
# 3

# %% [markdown]
# ## 3. Make Dense Layer

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam
from tensorflow.keras import layers

# %%
# Define the input layer
inputs = Input(shape=(X_train.shape[1],))

# Define the model architecture
x = Dense(128, activation='relu')(inputs)
x = Dense(128, activation='relu')(x)
predictions = Dense(3, activation='softmax')(x) 

# Create the model
model = Model(inputs=inputs, outputs=predictions)

# Compile the model
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 7)]               0
#
#  dense_41 (Dense)            (None, 128)               1024
#
#  dense_42 (Dense)            (None, 128)               16512
#
#  dense_43 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 17923 (70.01 KB)
# Trainable params: 17923 (70.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=50, batch_size=32, validation_split = 0.1, shuffle = True)
pred_DL = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1) # 배열에서 최댓값을 가지는 원소의 인덱스를 반환하는 함수
y_pred_class = np.argmax(pred_DL,axis=1)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6743 - accuracy: 0.6990 - val_loss: 0.7192 - val_accuracy: 0.5987
# Epoch 2/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6781 - accuracy: 0.7065 - val_loss: 0.7147 - val_accuracy: 0.6083
# Epoch 3/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6698 - accuracy: 0.6976 - val_loss: 0.7120 - val_accuracy: 0.6274
# Epoch 4/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6697 - accuracy: 0.7008 - val_loss: 0.7202 - val_accuracy: 0.6274
# Epoch 5/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6662 - accuracy: 0.7054 - val_loss: 0.7394 - val_accuracy: 0.6083
# Epoch 6/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6655 - accuracy: 0.6987 - val_loss: 0.7401 - val_accuracy: 0.6051
# Epoch 7/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.6670 - accuracy: 0.6987 - val_loss: 0.7145 - val_accuracy: 0.6115
# Epoch 8/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.6644 - accuracy: 0.7026 - val_loss: 0.7181 - val_accuracy: 0.6178
# Epoch 9/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6647 - accuracy: 0.6983 - val_loss: 0.7186 - val_accuracy: 0.6178
# Epoch 10/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.6592 - accuracy: 0.7019 - val_loss: 0.7126 - val_accuracy: 0.6178
# Epoch 11/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6642 - accuracy: 0.7008 - val_loss: 0.7326 - val_accuracy: 0.6146
# Epoch 12/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6600 - accuracy: 0.7037 - val_loss: 0.7152 - val_accuracy: 0.6401
# Epoch 13/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6569 - accuracy: 0.7132 - val_loss: 0.7171 - val_accuracy: 0.6242
# Epoch 14/50
# 89/89 [==============================] - 1s 12ms/step - loss: 0.6543 - accuracy: 0.7093 - val_loss: 0.7272 - val_accuracy: 0.6274
# Epoch 15/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.6552 - accuracy: 0.7054 - val_loss: 0.7206 - val_accuracy: 0.6529
# Epoch 16/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.6581 - accuracy: 0.7051 - val_loss: 0.7196 - val_accuracy: 0.6210
# Epoch 17/50
# 89/89 [==============================] - 1s 11ms/step - loss: 0.6520 - accuracy: 0.7090 - val_loss: 0.7246 - val_accuracy: 0.6210
# Epoch 18/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.6581 - accuracy: 0.7044 - val_loss: 0.7222 - val_accuracy: 0.6338
# Epoch 19/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6540 - accuracy: 0.7058 - val_loss: 0.7404 - val_accuracy: 0.6115
# Epoch 20/50
# 89/89 [==============================] - 0s 5ms/step - loss: 0.6511 - accuracy: 0.7090 - val_loss: 0.7246 - val_accuracy: 0.6306
# Epoch 21/50
# 89/89 [==============================] - 0s 6ms/step - loss: 0.6491 - accuracy: 0.7083 - val_loss: 0.7166 - val_accuracy: 0.6274
# Epoch 22/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6492 - accuracy: 0.7164 - val_loss: 0.7279 - val_accuracy: 0.6433
# Epoch 23/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6448 - accuracy: 0.7111 - val_loss: 0.7514 - val_accuracy: 0.6115
# Epoch 24/50
# 89/89 [==============================] - 1s 10ms/step - loss: 0.6459 - accuracy: 0.7139 - val_loss: 0.7218 - val_accuracy: 0.6369
# Epoch 25/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6482 - accuracy: 0.7100 - val_loss: 0.7391 - val_accuracy: 0.6369
# Epoch 26/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6447 - accuracy: 0.7125 - val_loss: 0.7209 - val_accuracy: 0.6306
# Epoch 27/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6417 - accuracy: 0.7129 - val_loss: 0.7300 - val_accuracy: 0.6306
# Epoch 28/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6402 - accuracy: 0.7136 - val_loss: 0.7366 - val_accuracy: 0.6274
# Epoch 29/50
# 89/89 [==============================] - 1s 9ms/step - loss: 0.6401 - accuracy: 0.7192 - val_loss: 0.7377 - val_accuracy: 0.6083
# Epoch 30/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6357 - accuracy: 0.7178 - val_loss: 0.7362 - val_accuracy: 0.6083
# Epoch 31/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6414 - accuracy: 0.7171 - val_loss: 0.7361 - val_accuracy: 0.6146
# Epoch 32/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6399 - accuracy: 0.7175 - val_loss: 0.7308 - val_accuracy: 0.6051
# Epoch 33/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6403 - accuracy: 0.7143 - val_loss: 0.7467 - val_accuracy: 0.6019
# Epoch 34/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6340 - accuracy: 0.7157 - val_loss: 0.7313 - val_accuracy: 0.6210
# Epoch 35/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6320 - accuracy: 0.7224 - val_loss: 0.7473 - val_accuracy: 0.6115
# Epoch 36/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6397 - accuracy: 0.7161 - val_loss: 0.7495 - val_accuracy: 0.6274
# Epoch 37/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6352 - accuracy: 0.7214 - val_loss: 0.7625 - val_accuracy: 0.6274
# Epoch 38/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6323 - accuracy: 0.7235 - val_loss: 0.7422 - val_accuracy: 0.6242
# Epoch 39/50
# 89/89 [==============================] - 0s 6ms/step - loss: 0.6297 - accuracy: 0.7235 - val_loss: 0.7410 - val_accuracy: 0.6338
# Epoch 40/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6306 - accuracy: 0.7253 - val_loss: 0.7476 - val_accuracy: 0.6274
# Epoch 41/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6392 - accuracy: 0.7217 - val_loss: 0.7545 - val_accuracy: 0.6369
# Epoch 42/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6259 - accuracy: 0.7221 - val_loss: 0.7449 - val_accuracy: 0.6210
# Epoch 43/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6303 - accuracy: 0.7246 - val_loss: 0.7357 - val_accuracy: 0.6146
# Epoch 44/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6282 - accuracy: 0.7129 - val_loss: 0.7344 - val_accuracy: 0.6401
# Epoch 45/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6221 - accuracy: 0.7235 - val_loss: 0.7543 - val_accuracy: 0.6369
# Epoch 46/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6259 - accuracy: 0.7164 - val_loss: 0.7345 - val_accuracy: 0.6369
# Epoch 47/50
# 89/89 [==============================] - 1s 8ms/step - loss: 0.6202 - accuracy: 0.7338 - val_loss: 0.7609 - val_accuracy: 0.6369
# Epoch 48/50
# 89/89 [==============================] - 1s 6ms/step - loss: 0.6156 - accuracy: 0.7278 - val_loss: 0.7408 - val_accuracy: 0.6369
# Epoch 49/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6185 - accuracy: 0.7231 - val_loss: 0.7544 - val_accuracy: 0.6274
# Epoch 50/50
# 89/89 [==============================] - 1s 7ms/step - loss: 0.6147 - accuracy: 0.7239 - val_loss: 0.7749 - val_accuracy: 0.6210
# 33/33 [==============================] - 0s 6ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#Accuracy of the predicted values
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       367
#            1       0.50      0.47      0.48       315
#            2       0.68      0.68      0.68       364
#
#     accuracy                           0.66      1046
#    macro avg       0.65      0.65      0.65      1046
# weighted avg       0.65      0.66      0.66      1046
#
# [[295  59  13]
#  [ 63 147 105]
#  [ 29  88 247]]
