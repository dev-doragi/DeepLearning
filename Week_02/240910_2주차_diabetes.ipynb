# %% [markdown]
# # 2주차

# %% [markdown]
# 1. 당뇨병 데이터를 가지고 머신러닝 5가지 분류를 수행.
#
#     (SVM, LR, RF, DT, KNN)
#
# 2. 동일한 데이터로 딥러닝 분류 수행하라. (dense layer 만 사용)
#
# 3. 해당 데이터에서 Outcome을 삭제하고 BMI를 예측하는 회귀를 수행하라.
#
# 4. 3번과 동일하지만 dense layer만 사용한 신경만으로 회귀를 수행하라.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv("C:\\Project\\Anaconda\\2nd_semester\\Data\\diabetes.csv")
#df = pd.read_csv("C:/Project/Anaconda/2nd_semester/Data/diabetes.csv") # \는 콜백문자 때문에 \\로 사용한다.
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# Age를 10으로 나누어서 새로운 열 생성
df['Age_group'] = (df['Age'] // 10) * 10

# countplot 그리기
sns.countplot(data=df, x="Age_group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Age_group
# 0                       0.627   50        1         50
# 1                       0.351   31        0         30
# 2                       0.672   32        1         30
# 3                       0.167   21        0         20
# 4                       2.288   33        1         30
# ..                        ...  ...      ...        ...
# 763                     0.171   63        0         60
# 764                     0.340   27        0         20
# 765                     0.245   30        0         30
# 766                     0.349   47        1         40
# 767                     0.315   23        0         20
#
# [768 rows x 10 columns]

# %%
# Age_group 별 Outcome 확인

# Assuming your data is in a DataFrame 'df'
# Filter for Outcome == 1
df_outcome_1 = df[df['Outcome'] == 1]

# Plot the count of Age_group where Outcome == 1
sns.countplot(data=df_outcome_1, x='Age_group')
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title('Count of Diabetes by Age Group')
plt.show()

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# Age_group                   0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# Age_group                   0
# dtype: int64

# %% [markdown]
# X= 피쳐 값
#
# y= 레이블 값 (결과 값)

# %%
X=df.drop('Outcome', axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Age_group
# 0                     0.627   50         50
# 1                     0.351   31         30
# 2                     0.672   32         30
# 3                     0.167   21         20
# 4                     2.288   33         30

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0)

X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 603            7      150             78             29      126  35.2
# 118            4       97             60             23        0  28.2
# 247            0      165             90             33      680  52.3
# 157            1      109             56             21      135  25.2
# 468            8      120              0              0        0  30.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Age_group
# 603                     0.692   54         50
# 118                     0.443   22         20
# 247                     0.427   23         20
# 157                     0.833   23         20
# 468                     0.183   38         30
# ..                        ...  ...        ...
# 763                     0.171   63         60
# 192                     0.383   36         30
# 629                     0.148   21         20
# 559                     0.300   35         30
# 684                     0.640   69         60
#
# [614 rows x 9 columns]

# %% [markdown]
# # 1. Machine Learning (Outcome)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import warnings # 필터 오류를 무시
warnings.filterwarnings('ignore')

# %% [markdown]
# #### confusion matrix?
# true positive //        true negative
#
#     TP          FP
#
#     FN          TN
#
#     - Accuracy(Precision): TP / TP + FP
#     - Recall:              TP / TP + FN

# %% [markdown]
# ## SVM (Support Vector Machine)

# %%
from sklearn.svm import SVC

clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train) # X_train(학습데이터)과 y_train(레이블)으로 학습

pred_svm = clf_svm.predict(X_test) # 이번에는 테스트 데이터로 테스트한 값을 pred_svm에 저장

print("\n--- SVM Classifier ---")
print('{:.5f}'.format(accuracy_score(y_test, pred_svm)))
print(confusion_matrix(y_test, pred_svm))
# Out:
# --- SVM Classifier ---
# 0.78571
# [[97 10]
#  [23 24]]

# %% [markdown]
# ## LR (Logistic Regression)

# %%
from sklearn.linear_model import LogisticRegression

# Build a logistic regression classifier and predict

clf_lr = LogisticRegression(random_state=0)
clf_lr.fit(X_train, y_train)

pred_lr = clf_lr.predict(X_test)

print ("\n--- Logistic Regression Classifier ---")
#print (accuracy_score(y_test, pred_lr))
print('{:.5f}'.format(accuracy_score(y_test, pred_lr)))
print (confusion_matrix(y_test, pred_lr))
# Out:
# --- Logistic Regression Classifier ---
# 0.81818
# [[97 10]
#  [18 29]]

# %% [markdown]
# ## RF (Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train, y_train)

pred_rf = rf_clf.predict(X_test)

print ("\n--- Radom Forest ---")
print('{:.5f}'.format(accuracy_score(y_test, pred_rf)))
print (confusion_matrix(y_test, pred_rf))
# Out:
# --- Radom Forest ---
# 0.78571
# [[90 17]
#  [16 31]]

# %% [markdown]
# ## DT (Decision Tree)

# %%
from sklearn.tree import DecisionTreeClassifier
# Build a decision tree classifier and predict

clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
print ('{:.5f}'.format(accuracy_score(y_test, pred_dt)))
print (confusion_matrix(y_test, pred_dt))
# Out:
# --- Decision Tree Classifier ---
# 0.79870
# [[89 18]
#  [13 34]]

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

# 모델 선택 (분류 문제인 경우)
knn_model = KNeighborsClassifier(n_neighbors=5)

# 모델 선택 (회귀 문제인 경우)
# knn_model = KNeighborsRegressor(n_neighbors=5)

# 모델 학습
knn_model.fit(X_train, y_train)

# 예측 수행
y_pred = knn_model.predict(X_test)

# 성능 평가 (분류 문제인 경우)
print("\n--- KNN ---")
print ('{:.5f}'.format(accuracy_score(y_test, y_pred)))
print (confusion_matrix(y_test, y_pred))

# 성능 평가 (회귀 문제인 경우)
# mse = mean_squared_error(y_test, y_pred)
# print("평균제곱오차:", mse)
# Out:
# --- KNN ---
# 0.76623
# [[88 19]
#  [17 30]]

# %% [markdown]
# # 2. Deep Learning (Outcome)

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values
y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 762            9       89             62              0        0  22.5
# 127            1      118             58             36       94  33.3
# 564            0       91             80              0        0  32.4
# 375           12      140             82             43      325  39.2
# 663            9      145             80             46      130  37.9
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age  Age_group
# 762                     0.142   33         30
# 127                     0.261   23         20
# 564                     0.601   27         20
# 375                     0.528   58         50
# 663                     0.637   40         40
# ..                        ...  ...        ...
# 763                     0.171   63         60
# 192                     0.383   36         30
# 629                     0.148   21         20
# 559                     0.300   35         30
# 684                     0.640   69         60
#
# [576 rows x 9 columns]

# %%
y_test.shape
# Out:
# (192, 2)

# %%
#Defining the model 
#분류 예제

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

model = Sequential()

model.add(Dense(15, input_shape=(X_train.shape[1], ), activation='relu'))
#input_shape: 입력 데이터의 모양을 지정한다. 첫 번째 레이어에서만 사용된다.
model.add(Dense(10, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

#출력 유닛 수는 클래스 수(레이블 수)와 동일하게 설정한다!!!!!!

model.compile(optimizer=Adam(learning_rate=0.02), loss='bce', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 15)                150
#
#  dense_22 (Dense)            (None, 10)                160
#
#  dense_23 (Dense)            (None, 6)                 66
#
#  dense_24 (Dense)            (None, 2)                 14
#
# =================================================================
# Total params: 390 (1.52 KB)
# Trainable params: 390 (1.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis=1) # 배열에서 최댓값을 가지는 원소의 인덱스를 반환하는 함수
y_pred_class = np.argmax(y_pred, axis=1)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 3s 41ms/step - loss: 2.6962 - accuracy: 0.5243 - val_loss: 0.7129 - val_accuracy: 0.6771
# Epoch 2/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7097 - accuracy: 0.6424 - val_loss: 0.6618 - val_accuracy: 0.6823
# Epoch 3/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6595 - accuracy: 0.6441 - val_loss: 0.6403 - val_accuracy: 0.6823
# Epoch 4/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6498 - accuracy: 0.6458 - val_loss: 0.6291 - val_accuracy: 0.6927
# Epoch 5/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6395 - accuracy: 0.6562 - val_loss: 0.6317 - val_accuracy: 0.6979
# Epoch 6/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6348 - accuracy: 0.6615 - val_loss: 0.6151 - val_accuracy: 0.6927
# Epoch 7/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6320 - accuracy: 0.6615 - val_loss: 0.6487 - val_accuracy: 0.6719
# Epoch 8/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6437 - accuracy: 0.6406 - val_loss: 0.6094 - val_accuracy: 0.6771
# Epoch 9/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6220 - accuracy: 0.6667 - val_loss: 0.5982 - val_accuracy: 0.6979
# Epoch 10/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6305 - accuracy: 0.6719 - val_loss: 0.5895 - val_accuracy: 0.7188
# Epoch 11/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6216 - accuracy: 0.6771 - val_loss: 0.6219 - val_accuracy: 0.6927
# Epoch 12/50
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6138 - accuracy: 0.6753 - val_loss: 0.5818 - val_accuracy: 0.7448
# Epoch 13/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0
50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5440 - accuracy: 0.7309 - val_loss: 0.4961 - val_accuracy: 0.7812
# Epoch 38/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5377 - accuracy: 0.7257 - val_loss: 0.4904 - val_accuracy: 0.7865
# Epoch 39/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5389 - accuracy: 0.7326 - val_loss: 0.4878 - val_accuracy: 0.7812
# Epoch 40/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5406 - accuracy: 0.7326 - val_loss: 0.5052 - val_accuracy: 0.7448
# Epoch 41/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5342 - accuracy: 0.7431 - val_loss: 0.4978 - val_accuracy: 0.7760
# Epoch 42/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5672 - accuracy: 0.6997 - val_loss: 0.4950 - val_accuracy: 0.7552
# Epoch 43/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5496 - accuracy: 0.7066 - val_loss: 0.4842 - val_accuracy: 0.7917
# Epoch 44/50
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5219 - accuracy: 0.7569 - val_loss: 0.5049 - val_accuracy: 0.7552
# Epoch 45/50
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5250 - accuracy: 0.7396 - val_loss: 0.5101 - val_accuracy: 0.7656
# Epoch 46/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.5330 - accuracy: 0.7274 - val_loss: 0.4996 - val_accuracy: 0.7552
# Epoch 47/50
# 18/18 [==============================] - 0s 15ms/step - loss: 0.5500 - accuracy: 0.7257 - val_loss: 0.5620 - val_accuracy: 0.6927
# Epoch 48/50
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5611 - accuracy: 0.7274 - val_loss: 0.5429 - val_accuracy: 0.7604
# Epoch 49/50
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5297 - accuracy: 0.7396 - val_loss: 0.5220 - val_accuracy: 0.7448
# Epoch 50/50
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5347 - accuracy: 0.7326 - val_loss: 0.5083 - val_accuracy: 0.7604
# 6/6 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.81       130
#            1       0.61      0.73      0.66        62
#
#     accuracy                           0.76       192
#    macro avg       0.73      0.75      0.74       192
# weighted avg       0.78      0.76      0.77       192
#
# [[101  29]
#  [ 17  45]]

# %% [markdown]
# # 3. Regression (BMI)

# %%
df = pd.read_csv("C:\\Project\\Anaconda\\2nd_semester\\Data\\diabetes.csv")
#df = pd.read_csv("C:/Project/Anaconda/2nd_semester/Data/diabetes.csv") # \는 콜백문자 때문에 \\로 사용한다.
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X=df.drop('BMI', axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0            6      148             72             35        0
# 1            1       85             66             29        0
# 2            8      183             64              0        0
# 3            1       89             66             23       94
# 4            0      137             40             35      168
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y=df['BMI']
y.value_counts()
# Out:
# BMI
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: count, Length: 248, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, shuffle=True, random_state=12)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (614, 8) (614,)
# (154, 8) (154,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ly_preds = model.predict(X_test)
mse = mean_squared_error(ly_preds, y_test)
print('--- MSE ---')
print('{:.5f}'.format(mse))
# Out:
# --- MSE ---
# 47.94585

# %%
# 예측값과 실제 값 차이를 산접도로 표시, 노란색 예측

plt.figure(figsize=(10,5))
plt.scatter(X_test['DiabetesPedigreeFunction'], y_test, label='y_test')
plt.scatter(X_test['DiabetesPedigreeFunction'], ly_preds, c='y', label='ly_preds')
#plt.plot(X_train, model.predict(X_train), color='blue')
plt.show()

# %% [markdown]
# # 4. Deep Learning (BMI)

# %%
df = pd.read_csv("C:\\Project\\Anaconda\\2nd_semester\\Data\\diabetes.csv")
#df = pd.read_csv("C:/Project/Anaconda/2nd_semester/Data/diabetes.csv") # \는 콜백문자 때문에 \\로 사용한다.

X = df.drop(['BMI', 'Outcome'], axis=1)  # 'Outcome'은 제외, BMI는 예측 대상
y = df['BMI']

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 762            9       89             62              0        0
# 127            1      118             58             36       94
# 564            0       91             80              0        0
# 375           12      140             82             43      325
# 663            9      145             80             46      130
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 192            7      159             66              0        0
# 629            4       94             65             22        0
# 559           11       85             74              0        0
# 684            5      136             82              0        0
#
#      DiabetesPedigreeFunction  Age
# 762                     0.142   33
# 127                     0.261   23
# 564                     0.601   27
# 375                     0.528   58
# 663                     0.637   40
# ..                        ...  ...
# 763                     0.171   63
# 192                     0.383   36
# 629                     0.148   21
# 559                     0.300   35
# 684                     0.640   69
#
# [576 rows x 7 columns]

# %%
y_test
# Out:
# 661    42.9
# 122    33.6
# 113    34.0
# 14     25.8
# 529    24.6
#        ...
# 366    27.6
# 301    31.6
# 382    25.4
# 140    21.1
# 463    27.6
# Name: BMI, Length: 192, dtype: float64

# %% [markdown]
# MAE는 Mean Absolute Error의 약자로, 예측 값과 실제 값 간의 절대 오차의 평균을 측정하는 지표이다.

# %%
# 신경망 모델 구성
model = Sequential()

# 입력층과 은닉층
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))

# 출력층 (회귀를 위한 출력)
model.add(Dense(1, activation='relu'))

# 모델 컴파일 (회귀 문제이므로 손실 함수는 mean_squared_error 사용)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# 모델 요약 출력
model.summary()
# Out:
# WARNING:tensorflow:From C:\Anaconda\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 64)                512
#
#  dense_26 (Dense)            (None, 32)                2080
#
#  dense_27 (Dense)            (None, 16)                528
#
#  dense_28 (Dense)            (None, 8)                 136
#
#  dense_29 (Dense)            (None, 4)                 36
#
#  dense_30 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 3297 (12.88 KB)
# Trainable params: 3297 (12.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# 테스트 데이터로 평가
test_loss, test_mae = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 4s 43ms/step - loss: 859.8428 - mae: 28.3050 - val_loss: 594.8319 - val_mae: 23.3973
# Epoch 2/100
# 15/15 [==============================] - 0s 10ms/step - loss: 420.3263 - mae: 18.6627 - val_loss: 179.6123 - val_mae: 11.7108
# Epoch 3/100
# 15/15 [==============================] - 0s 10ms/step - loss: 182.6714 - mae: 10.2948 - val_loss: 117.6762 - val_mae: 8.2728
# Epoch 4/100
# 15/15 [==============================] - 0s 10ms/step - loss: 114.8095 - mae: 8.0993 - val_loss: 85.1383 - val_mae: 7.1148
# Epoch 5/100
# 15/15 [==============================] - 0s 10ms/step - loss: 75.0287 - mae: 6.8425 - val_loss: 75.0353 - val_mae: 6.3953
# Epoch 6/100
# 15/15 [==============================] - 0s 10ms/step - loss: 66.0936 - mae: 6.3294 - val_loss: 77.6180 - val_mae: 6.4998
# Epoch 7/100
# 15/15 [==============================] - 0s 10ms/step - loss: 62.9082 - mae: 6.1774 - val_loss: 71.5190 - val_mae: 6.1363
# Epoch 8/100
# 15/15 [==============================] - 0s 10ms/step - loss: 60.9314 - mae: 6.0857 - val_loss: 69.2454 - val_mae: 6.0479
# Epoch 9/100
# 15/15 [==============================] - 0s 10ms/step - loss: 58.9106 - mae: 5.9550 - val_loss: 68.0337 - val_mae: 5.9816
# Epoch 10/100
# 15/15 [==============================] - 0s 10ms/step - loss: 57.5718 - mae: 5.9084 - val_loss: 64.7804 - val_mae: 5.8399
# Epoch 11/100
# 15/15 [==============================] - 0s 10ms/step - loss: 55.3509 - mae: 5.7751 - val_loss: 66.0358 - val_mae: 5.8863
# Epoch 12/100
# 15/15 [==============================] - 0s 11ms/step - loss: 55.3976 - mae: 5.7935 - val_loss: 65.6298 - val_mae: 5.8519
# Epoch 13/100
# 15/15 [==============================] - 0s 10ms/step - loss: 55.3045 - mae: 5.7448 - val_loss: 61.5005 - val_mae: 5.6277
# Epoch 14/100
# 15/15 [==============================] - 0s 10ms/step - loss: 51.9895 - mae: 5.5738 - val_loss: 60.3687 - val_mae: 5.5489
# Epoch 15/100
# 15/15 [==============================] - 0s 10ms/step - loss: 49.9810 - mae: 5.3887 - val_loss: 59.1121 - val_mae: 5.5028
# Epoch 16/100
# 15/15 [==============================] - 0s 9ms/step - loss: 49.0677 - mae: 5.3522 - val_loss: 57.2287 - val_mae: 5.3968
# Epoch 17/100
# 15/15 [==============================] - 0s 10ms/step - loss: 48.2369 - mae: 5.3072 - val_loss: 56.7644 - val_mae: 5.3588
# Epoch 18/100
# 15/15 [==============================] - 0s 10ms/step - loss: 47.6397 - mae: 5.2493 - val_loss: 56.1374 - val_mae: 5.3141
# Epoch 19/100
# 15/15 [==============================] - 0s 10ms/step - loss: 46.6161 - mae: 5.1915 - val_loss: 56.0188 - val_mae: 5.2926
# %%
print(f'Test MSE: {test_loss}')
print(f'Test MAE: {test_mae}')
# Out:
# Test MSE: 56.27272415161133
# Test MAE: 5.533458709716797

# %% [markdown]
# # CNN

# %% [markdown]
# CNN은 Convolution Neural Network의 약자이다.
#
# 덴스 레이어에서 전체 노드가 연결되어 유닛 간 특징 추출이 어려웠던 반면,
#
# CNN에서는 상위 노드와 하위 노드가 '부분적'으로 연결되어 유닛 간 특징 추출이 용이하다.

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X=df.drop('Outcome', axis=1)
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y=df['Outcome']
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#one hot encoding 하기

y = pd.get_dummies(y).values

# %%
y
# Out:
# array([[False,  True],
#        [ True, False],
#        [False,  True],
#        ...,
#        [ True, False],
#        [False,  True],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
# random_state는 데이터를 무작위로 나누거나 섞을 때 사용되는 난수 발생기의 시드(seed) 값

# %%
X_test.shape
# Out:
# (192, 8)

# %%
y_train.shape
# Out:
# (576, 2)

# %%
# 데이터 셋을 만들고 해당 셋으로 train, test를 만든다.

def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :8], sequences[end_ix-1, 8:]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# Merge train and test X/y data to apply sequence transformation function
y_train_array = np.array(y_train)
# np.c_ : 배열을 열 방향으로 이어붙인다.
train_set = np.c_[X_train, y_train_array]

y_test_array = np.array(y_test)
test_set = np.c_[X_test, y_test_array]

# 8개의 features와 2개의 label이 합쳐진 train_set, test_set
print(train_set)
# Out:
# [[  9.  89.  62. ...  33.   1.   0.]
#  [  1. 118.  58. ...  23.   1.   0.]
#  [  0.  91.  80. ...  27.   1.   0.]
#  ...
#  [  4.  94.  65. ...  21.   1.   0.]
#  [ 11.  85.  74. ...  35.   1.   0.]
#  [  5. 136.  82. ...  69.   1.   0.]]

# %%
y_train
# Out:
# array([[ True, False],
#        [ True, False],
#        [ True, False],
#        ...,
#        [ True, False],
#        [ True, False],
#        [ True, False]])

# %%
# Apply sequence transformation using time step of 25 for both train and test data
# All sensing modalities are recorded at a sampling rate of 50 Hz, which is considered sufficient for capturing human activity.

X_train, y_train = split_sequences(train_set, 5)
print(X_train.shape, y_train.shape)

X_test, y_test = split_sequences(test_set, 5)
print(X_test.shape, y_test.shape)
# Out:
# (572, 5, 8) (572, 2)
# (188, 5, 8) (188, 2)

# %%
# 각각 스텝 수, feature 수, label 수
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 5 8 2

# %%
X_train.shape[1]
# Out:
# 5

# %%
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Input
from keras.layers import Dense, Flatten, Dropout

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras import layers

# %%
# 신경망 모델 구축
inputs = Input(shape=(n_timesteps, n_features,))

x = Conv1D(32, 2, activation='relu')(inputs)
x = Dense(64, activation='relu')(x)
x = layers.Dropout(0.3)(x) # 드롭아웃으로 노드 비활성화
x = Flatten()(x)
prediction = Dense(n_outputs, activation='softmax')(x)

model = Model(inputs=inputs, outputs=prediction)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 5, 8)]            0
#
#  conv1d_3 (Conv1D)           (None, 4, 32)             544
#
#  dense_36 (Dense)            (None, 4, 64)             2112
#
#  dropout_2 (Dropout)         (None, 4, 64)             0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_37 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 3170 (12.38 KB)
# Trainable params: 3170 (12.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

# 신경망 훈련, 검증 데이터 전달
#  callbacks = [early_stopping],
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=100, batch_size=144, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 0.3914 - accuracy: 0.8077 - val_loss: 0.6370 - val_accuracy: 0.6915 - 191ms/epoch - 48ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.4285 - accuracy: 0.8042 - val_loss: 0.6367 - val_accuracy: 0.7340 - 91ms/epoch - 23ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.4016 - accuracy: 0.8077 - val_loss: 0.6447 - val_accuracy: 0.7181 - 100ms/epoch - 25ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.4123 - accuracy: 0.7937 - val_loss: 0.6574 - val_accuracy: 0.6915 - 106ms/epoch - 26ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.3973 - accuracy: 0.8007 - val_loss: 0.6563 - val_accuracy: 0.6862 - 102ms/epoch - 25ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.4029 - accuracy: 0.8147 - val_loss: 0.6484 - val_accuracy: 0.6862 - 94ms/epoch - 24ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.4024 - accuracy: 0.8199 - val_loss: 0.6405 - val_accuracy: 0.7074 - 112ms/epoch - 28ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.4064 - accuracy: 0.8217 - val_loss: 0.6394 - val_accuracy: 0.7128 - 105ms/epoch - 26ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.3873 - accuracy: 0.8287 - val_loss: 0.6464 - val_accuracy: 0.7181 - 102ms/epoch - 25ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.3987 - accuracy: 0.7937 - val_loss: 0.6544 - val_accuracy: 0.7128 - 118ms/epoch - 29ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.4053 - accuracy: 0.8129 - val_loss: 0.6547 - val_accuracy: 0.7074 - 116ms/epoch - 29ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.3834 - accuracy: 0.8287 - val_loss: 0.6523 - val_accuracy: 0.7128 - 173ms/epoch - 43ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.3910 - accuracy: 0.8147 - val_loss: 0.6510 - val_accuracy: 0.7074 - 180ms/epoch - 45ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.3845 - accuracy: 0.8164 - val_loss: 0.6500 - val_accuracy: 0.6862 - 189ms/epoch - 47ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.3810 - accuracy: 0.8234 - val_loss: 0.6461 - val_accuracy: 0.6968 - 179ms/epoch - 45ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.3585 - accuracy: 0.8287 - val_loss: 0.6457 - val_accuracy: 0.7021 - 183ms/epoch - 46ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.3843 - accuracy: 0.8322 - val_loss: 0.6482 - val_accuracy: 0.6915 - 185ms/epoch - 46ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.3883 - accuracy: 0.8269 - val_loss: 0.6485 - val_accuracy: 0.6915 - 170ms/epoch - 42ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.3628 - accuracy: 0.8514 - val_loss: 0.6554 - val_accuracy: 0.7021 - 102ms/epoch - 25ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.3882 - accuracy: 0.8339 - val_loss: 0.6614 - val_accuracy: 0.6968 - 107ms/epoch - 27ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.3613 - accuracy: 0.8392 - val_loss: 0.6622 - val_accuracy: 0.6968 - 105ms/epoch - 26ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.3815 - accuracy: 0.8339 - val_loss: 0.6629 - val_accuracy: 0.6915 - 114ms/epoch - 28ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.3728 - accuracy: 0.8147 - val_loss: 0.6640 - val_accuracy: 0.6915 - 110ms/epoch - 27ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.3633 - accuracy: 0.8287 - val_loss: 0.6656 - val_accuracy: 0.7074 - 109ms/epoch - 27ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.3642 - accuracy: 0.8269 - val_loss: 0.6586 - val_accuracy: 0.6968 - 109ms/epoch - 27ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.3615 - accuracy: 0.8287 - val_loss: 0.6490 - val_accuracy: 0.7021 - 104ms/epoch - 26ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.3884 - accuracy: 0.8322 - val_loss: 0.6457 - val_accuracy: 0.6862 - 158ms/epoch - 40ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.3570 - accuracy: 0.8462 - val_loss: 0.6455 - val_accuracy: 0.6755 - 145ms/epoch - 36ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.3694 - accuracy: 0.8182 - val_loss: 0.6457 - val_accuracy: 0.6755 - 156ms/epoch - 39ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.3594 - accuracy: 0.8339 - val_loss: 0.6443 - val_accuracy: 0.6915 - 146ms/epoch - 36ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.3415 - accuracy: 0.8531 - val_loss: 0.6426 - val_accuracy: 0.6809 - 140ms/epoch - 35ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.3578 - accuracy: 0.8409 - val_loss: 0.6443 - val_accuracy: 0.6755 - 130ms/epoch - 33ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.3785 - accuracy: 0.8374 - val_loss: 0.6455 - val_accuracy: 0.6862 - 102ms/epoch - 25ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.3481 - accuracy: 0.8357 - val_loss: 0.6404 - val_accuracy: 0.6915 - 104ms/epoch - 26ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.3669 - accuracy: 0.8427 - val_loss: 0.6431 - val_accuracy: 0.6968 - 93ms/epoch - 23ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.3834 - accuracy: 0.8199 - val_loss: 0.6403 - val_accuracy: 0.6915 - 99ms/epoch - 25ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.3400 - accuracy: 0.8479 - val_loss: 0.6380 - val_accuracy: 0.6968 - 104ms/epoch - 26ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.3625 - accuracy: 0.8479 - val_loss: 0.6360 - val_accuracy: 0.6915 - 109ms/epoch - 27ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.3658 - accuracy: 0.8427 - val_loss: 0.6361 - val_accuracy: 0.6968 - 110ms/epoch - 27ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.3450 - accuracy: 0.8357 - val_loss: 0.6396 - val_accuracy: 0.6862 - 110ms/epoch - 27ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.3477 - accuracy: 0.8339 - val_loss: 0.6402 - val_accuracy: 0.6862 - 102ms/epoch - 25ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.3441 - accuracy: 0.8444 - val_loss: 0.6471 - val_accuracy: 0.6809 - 208ms/epoch - 52ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.3587 - accuracy: 0.8357 - val_loss: 0.6543 - val_accuracy: 0.6755 - 106ms/epoch - 27ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.3453 - accuracy: 0.8444 - val_loss: 0.6521 - val_accuracy: 0.6862 - 127ms/epoch - 32ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.3437 - accuracy: 0.8531 - val_loss: 0.6505 - val_accuracy: 0.6915 - 185ms/epoch - 46ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.3392 - accuracy: 0.8479 - val_loss: 0.6501 - val_accuracy: 0.6915 - 189ms/epoch - 47ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.3244 - accuracy: 0.8531 - val_loss: 0.6480 - val_accuracy: 0.6968 - 163ms/epoch - 41ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.3538 - accuracy: 0.8514 - val_loss: 0.6470 - val_accuracy: 0.7074 - 140ms/epoch - 35ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.3437 - accuracy: 0.8427 - val_loss: 0.6490 - val_accuracy: 0.7021 - 158ms/epoch - 39ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.3543 - accuracy: 0.8322 - val_loss: 0.6491 - val_accuracy: 0.6968 - 143ms/epoch - 36ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.3453 - accuracy: 0.8252 - val_loss: 0.6543 - val_accuracy: 0.7021 - 143ms/epoch - 36ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.3661 - accuracy: 0.8322 - val_loss: 0.6578 - val_accuracy: 0.6915 - 104ms/epoch - 26ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.3441 - accuracy: 0.8479 - val_loss: 0.6605 - val_accuracy: 0.6968 - 157ms/epoch - 39ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.3534 - accuracy: 0.8427 - val_loss: 0.6528 - val_accuracy: 0.6862 - 158ms/epoch - 40ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.3174 - accuracy: 0.8636 - val_loss: 0.6472 - val_accuracy: 0.6915 - 144ms/epoch - 36ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.3504 - accuracy: 0.8531 - val_loss: 0.6447 - val_accuracy: 0.6915 - 183ms/epoch - 46ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.3264 - accuracy: 0.8724 - val_loss: 0.6472 - val_accuracy: 0.6862 - 187ms/epoch - 47ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.3448 - accuracy: 0.8392 - val_loss: 0.6597 - val_accuracy: 0.6755 - 183ms/epoch - 46ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.3322 - accuracy: 0.8462 - val_loss: 0.6648 - val_accuracy: 0.6809 - 187ms/epoch - 47ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.3412 - accuracy: 0.8444 - val_loss: 0.6569 - val_accuracy: 0.6809 - 179ms/epoch - 45ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.3329 - accuracy: 0.8462 - val_loss: 0.6518 - val_accuracy: 0.6915 - 178ms/epoch - 45ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.3413 - accuracy: 0.8514 - val_loss: 0.6536 - val_accuracy: 0.6915 - 181ms/epoch - 45ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.3245 - accuracy: 0.8462 - val_loss: 0.6567 - val_accuracy: 0.6915 - 187ms/epoch - 47ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.3178 - accuracy: 0.8706 - val_loss: 0.6632 - val_accuracy: 0.6915 - 181ms/epoch - 45ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.3237 - accuracy: 0.8392 - val_loss: 0.6604 - val_accuracy: 0.6968 - 183ms/epoch - 46ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.3197 - accuracy: 0.8497 - val_loss: 0.6599 - val_accuracy: 0.7074 - 104ms/epoch - 26ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.3236 - accuracy: 0.8514 - val_loss: 0.6636 - val_accuracy: 0.7128 - 105ms/epoch - 26ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.3254 - accuracy: 0.8584 - val_loss: 0.6650 - val_accuracy: 0.7074 - 96ms/epoch - 24ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.3241 - accuracy: 0.8636 - val_loss: 0.6654 - val_accuracy: 0.6915 - 108ms/epoch - 27ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.3252 - accuracy: 0.8514 - val_loss: 0.6665 - val_accuracy: 0.6968 - 106ms/epoch - 27ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.3149 - accuracy: 0.8619 - val_loss: 0.6692 - val_accuracy: 0.6862 - 100ms/epoch - 25ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.3336 - accuracy: 0.8409 - val_loss: 0.6672 - val_accuracy: 0.6968 - 116ms/epoch - 29ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 0.3083 - accuracy: 0.8706 - val_loss: 0.6634 - val_accuracy: 0.6968 - 106ms/epoch - 27ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 0.3041 - accuracy: 0.8794 - val_loss: 0.6676 - val_accuracy: 0.7021 - 126ms/epoch - 31ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 0.3375 - accuracy: 0.8497 - val_loss: 0.6700 - val_accuracy: 0.6968 - 136ms/epoch - 34ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 0.3285 - accuracy: 0.8566 - val_loss: 0.6678 - val_accuracy: 0.6915 - 146ms/epoch - 37ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 0.3191 - accuracy: 0.8811 - val_loss: 0.6603 - val_accuracy: 0.6915 - 185ms/epoch - 46ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 0.3058 - accuracy: 0.8829 - val_loss: 0.6632 - val_accuracy: 0.6915 - 188ms/epoch - 47ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 0.3111 - accuracy: 0.8601 - val_loss: 0.6580 - val_accuracy: 0.6809 - 173ms/epoch - 43ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 0.2929 - accuracy: 0.8706 - val_loss: 0.6534 - val_accuracy: 0.7128 - 208ms/epoch - 52ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 0.3109 - accuracy: 0.8566 - val_loss: 0.6599 - val_accuracy: 0.7021 - 189ms/epoch - 47ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 0.3256 - accuracy: 0.8566 - val_loss: 0.6612 - val_accuracy: 0.7021 - 184ms/epoch - 46ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 0.3180 - accuracy: 0.8514 - val_loss: 0.6673 - val_accuracy: 0.7074 - 160ms/epoch - 40ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 0.3099 - accuracy: 0.8619 - val_loss: 0.6775 - val_accuracy: 0.6862 - 159ms/epoch - 40ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 0.3110 - accuracy: 0.8654 - val_loss: 0.6730 - val_accuracy: 0.7234 - 107ms/epoch - 27ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 0.3172 - accuracy: 0.8759 - val_loss: 0.6775 - val_accuracy: 0.7021 - 99ms/epoch - 25ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 0.2936 - accuracy: 0.8706 - val_loss: 0.6933 - val_accuracy: 0.6702 - 107ms/epoch - 27ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 0.3079 - accuracy: 0.8636 - val_loss: 0.6905 - val_accuracy: 0.6755 - 102ms/epoch - 26ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 0.3111 - accuracy: 0.8689 - val_loss: 0.6831 - val_accuracy: 0.7021 - 98ms/epoch - 24ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 0.2979 - accuracy: 0.8741 - val_loss: 0.6868 - val_accuracy: 0.6968 - 111ms/epoch - 28ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 0.2736 - accuracy: 0.8916 - val_loss: 0.6879 - val_accuracy: 0.6915 - 103ms/epoch - 26ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 0.2849 - accuracy: 0.8829 - val_loss: 0.6921 - val_accuracy: 0.6862 - 99ms/epoch - 25ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 0.3113 - accuracy: 0.8619 - val_loss: 0.6968 - val_accuracy: 0.6862 - 106ms/epoch - 27ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 0.3249 - accuracy: 0.8514 - val_loss: 0.6958 - val_accuracy: 0.6862 - 117ms/epoch - 29ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 0.2970 - accuracy: 0.8654 - val_loss: 0.6978 - val_accuracy: 0.6809 - 100ms/epoch - 25ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 0.2748 - accuracy: 0.8916 - val_loss: 0.7075 - val_accuracy: 0.6755 - 110ms/epoch - 28ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 0.2795 - accuracy: 0.8916 - val_loss: 0.6976 - val_accuracy: 0.6968 - 109ms/epoch - 27ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 0.3096 - accuracy: 0.8619 - val_loss: 0.7016 - val_accuracy: 0.7021 - 108ms/epoch - 27ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 0.3041 - accuracy: 0.8741 - val_loss: 0.7047 - val_accuracy: 0.6862 - 98ms/epoch - 25ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 0.2610 - accuracy: 0.8899 - val_loss: 0.7047 - val_accuracy: 0.6755 - 137ms/epoch - 34ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 훈련 손실(training loss)과 검증 손실(validation loss) 추출
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

# 에포크(epoch) 범위 생성
epochs = range(1, len(loss) + 1)

# 훈련 손실(training loss)과 검증 손실(validation loss) 시각화
plt.plot(epochs, loss, 'y', label='Training loss')  # 훈련 손실을 노란색(yellow)으로 플롯
plt.plot(epochs, val_loss, 'r', label='Validation loss')  # 검증 손실을 빨간색(red)으로 플롯
plt.title('Training and validation loss')  # 그래프 제목 설정
plt.xlabel('Epochs')  # x축 레이블 설정
plt.ylabel('Loss')  # y축 레이블 설정
plt.legend()  # 범례(legend) 표시
plt.show()  # 그래프 출력

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print("\n----------------classification_report-----------------")
print(classification_report(y_test_class, y_pred_class))
print("\n------------------confusion_matrix--------------------")
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
# ----------------classification_report-----------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.81       130
#            1       0.61      0.73      0.66        62
#
#     accuracy                           0.76       192
#    macro avg       0.73      0.75      0.74       192
# weighted avg       0.78      0.76      0.77       192
#
#
# ------------------confusion_matrix--------------------
# [[101  29]
#  [ 17  45]]
