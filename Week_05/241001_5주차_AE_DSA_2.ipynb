# %% [markdown]
# # 5주차

# %% [markdown]
# Auto Encoder 사용하여 DSA 분석
#
# - 2nd AE 실습
#
# (수정된 신용카드 거래 소스올리면, 그걸 해보고 수행한후
#
# 응용해서 아래 실습)
#
# 1. DSA데이터에서 sitting(normal) jumping(abnormal)만 남김
#
# 2. 두개 activity를 섞어서 training / test
#
# 3. training를 다시 training/valid
#
# 4. training/valid에서 jumping 데이터를 삭제 ( sitting를 정상데이터로 사용)
#
# 5. AE로 valid를 목표로 training을 학습
#
# 6. sitting에 학습된 모델을 가지고,
#
# AE에 넣어서 Reconstruction error(입력/출력차이)를 구함
#
# 7. 적당한 threshold값으로 분류수행
#
# 8. accuracy를 구함

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From C:\Users\Choij\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv("C:/Project/DeepLearning/Data/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
df.shape
# Out:
# (9120, 272)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['T_xacc_mean', 'T_xacc_max', 'T_xacc_min', 'T_xacc_var', 'T_xacc_std',
#        'T_xacc_skew', 'T_yacc_mean', 'T_yacc_max', 'T_yacc_min', 'T_yacc_var',
#        ...
#        'LL_ymag_std', 'LL_ymag_skew', 'LL_zmag_mean', 'LL_zmag_max',
#        'LL_zmag_min', 'LL_zmag_var', 'LL_zmag_std', 'LL_zmag_skew', 'activity',
#        'people'],
#       dtype='object', length=272)

# %%
df['activity'].value_counts()
# Out:
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: activity, dtype: int64

# %% [markdown]
# ### 1.DSA데이터에서 sitting(normal), jumping(abnormal)만 남기기

# %%
df_filtered = df[df['activity'].isin(['sitting', 'jumping'])]
df_filtered = df_filtered.drop('people', axis=1)
df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729   sitting
# 1  7.032302e-07     0.000839      0.347471   sitting
# 2  6.268222e-07     0.000792      0.045579   sitting
# 3  8.011245e-07     0.000895      0.240690   sitting
# 4  6.853423e-07     0.000828      0.258429   sitting
#
# [5 rows x 271 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
df_filtered['activity'] = label_encoder.fit_transform(df_filtered['activity'])

df_filtered.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 0     1.083150      1.1832     0.99744    0.002208  ...  6.267229e-07
# 1     1.140865      1.2129     1.05810    0.000784  ...  7.403458e-07
# 2     1.140962      1.2128     1.07960    0.000508  ...  5.802523e-07
# 3     1.165260      1.3170     1.07870    0.002173  ...  5.398837e-07
# 4     1.187504      1.2574     1.09450    0.000662  ...  6.787533e-07
#
#    LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0     0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1     0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2     0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3     0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4     0.000824     -0.148229     -0.055801    -0.053313    -0.057815
#
#     LL_zmag_var  LL_zmag_std  LL_zmag_skew  activity
# 0  6.778722e-07     0.000823      0.036729         1
# 1  7.032302e-07     0.000839      0.347471         1
# 2  6.268222e-07     0.000792      0.045579         1
# 3  8.011245e-07     0.000895      0.240690         1
# 4  6.853423e-07     0.000828      0.258429         1
#
# [5 rows x 271 columns]

# %%
df_filtered['activity'].value_counts()
# Out:
# 1    480
# 0    480
# Name: activity, dtype: int64

# %% [markdown]
# sitting = Normal = 1
#
# jumping = Abnormal = 0

# %%
LABELS = ["Normal", "Abnormal"]

# %%
normal = df_filtered[df_filtered.activity == 1]
abnormal = df_filtered[df_filtered.activity == 0]
normal.shape
# Out:
# (480, 271)

# %%
abnormal.shape
# Out:
# (480, 271)

# %%
X_train, X_test = train_test_split(df_filtered, test_size=0.2, random_state=12)
X_train = X_train[X_train.activity == 1]
X_train = X_train.drop(['activity'], axis=1)

y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

X_train = X_train.values
X_test = X_test.values

X_train
# Out:
# array([[ 6.82727920e+00,  7.04710000e+00,  6.74950000e+00, ...,
#          6.14900090e-07,  7.84155654e-04,  2.01303493e-02],
#        [ 9.26134240e+00,  9.36300000e+00,  9.13990000e+00, ...,
#          4.79095897e-07,  6.92167535e-04, -3.39685410e-01],
#        [ 9.63063520e+00,  9.71860000e+00,  9.52500000e+00, ...,
#          7.72694516e-07,  8.79030441e-04, -3.23493433e-01],
#        ...,
#        [ 6.87320640e+00,  7.08540000e+00,  6.74960000e+00, ...,
#          7.07429677e-07,  8.41088389e-04, -9.70400942e-02],
#        [ 6.90843120e+00,  6.96630000e+00,  6.84680000e+00, ...,
#          4.44962297e-07,  6.67054943e-04, -1.59079611e-01],
#        [ 8.92051840e+00,  9.06070000e+00,  8.77770000e+00, ...,
#          4.12922581e-07,  6.42590523e-04,  1.43819966e-02]])

# %%
X_train.shape
# Out:
# (394, 270)

# %% [markdown]
# ### 4. AE로 sitting 정보만 가진 Train 데이터로 모델 학습

# %%
# 오토인코더 모델

input_dim = X_train.shape[1]
encoding_dim = 14  # 인코딩 차원을 설정 (임의로 설정한 값, 조정 가능)

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
encoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(int(encoding_dim / 2), activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 270)]             0
#
#  dense_12 (Dense)            (None, 14)                3794
#
#  dense_13 (Dense)            (None, 7)                 105
#
#  dense_14 (Dense)            (None, 7)                 56
#
#  dense_15 (Dense)            (None, 270)               2160
#
# =================================================================
# Total params: 6115 (23.89 KB)
# Trainable params: 6115 (23.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 3. 모델 학습
# 훈련데이터의 0.25 을 validation data로 사용
history = autoencoder.fit(X_train, X_train, epochs=50, batch_size=256, shuffle=True, validation_split = 0.25)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 116ms/step - loss: 5.5705 - val_loss: 5.5412
# Epoch 2/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5611 - val_loss: 5.5350
# Epoch 3/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.5550 - val_loss: 5.5312
# Epoch 4/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.5512 - val_loss: 5.5290
# Epoch 5/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5490 - val_loss: 5.5274
# Epoch 6/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5474 - val_loss: 5.5258
# Epoch 7/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5458 - val_loss: 5.5243
# Epoch 8/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.5442 - val_loss: 5.5225
# Epoch 9/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.5423 - val_loss: 5.5200
# Epoch 10/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.5398 - val_loss: 5.5167
# Epoch 11/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5364 - val_loss: 5.5121
# Epoch 12/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.5319 - val_loss: 5.5064
# Epoch 13/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5259 - val_loss: 5.4984
# Epoch 14/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.5177 - val_loss: 5.4881
# Epoch 15/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.5066 - val_loss: 5.4749
# Epoch 16/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.4930 - val_loss: 5.4563
# Epoch 17/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.4741 - val_loss: 5.4336
# Epoch 18/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.4512 - val_loss: 5.4096
# Epoch 19/50
# 2/2 [==============================] - 0s 38ms/step - loss: 5.4271 - val_loss: 5.3817
# Epoch 20/50
# 2/2 [==============================] - 0s 29ms/step - loss: 5.3994 - val_loss: 5.3492
# Epoch 21/50
# 2/2 [==============================] - 0s 28ms/step - loss: 5.3670 - val_loss: 5.3105
# Epoch 22/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.3279 - val_loss: 5.2645
# Epoch 23/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.2816 - val_loss: 5.2114
# Epoch 24/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.2292 - val_loss: 5.1539
# Epoch 25/50
# 2/2 [==============================] - 0s 20ms/step - loss: 5.1721 - val_loss: 5.0931
# Epoch 26/50
# 2/2 [==============================] - 0s 21ms/step - loss: 5.1118 - val_loss: 5.0299
# Epoch 27/50
# 2/2 [==============================] - 0s 19ms/step - loss: 5.0490 - val_loss: 4.9666
# Epoch 28/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.9868 - val_loss: 4.9069
# Epoch 29/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.9277 - val_loss: 4.8526
# Epoch 30/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.8742 - val_loss: 4.8058
# Epoch 31/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.8280 - val_loss: 4.7665
# Epoch 32/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.7893 - val_loss: 4.7340
# Epoch 33/50
# 2/2 [==============================] - 0s 22ms/step - loss: 4.7574 - val_loss: 4.7078
# Epoch 34/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.7316 - val_loss: 4.6866
# Epoch 35/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.7107 - val_loss: 4.6698
# Epoch 36/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6942 - val_loss: 4.6566
# Epoch 37/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6812 - val_loss: 4.6465
# Epoch 38/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6710 - val_loss: 4.6385
# Epoch 39/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6629 - val_loss: 4.6322
# Epoch 40/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6565 - val_loss: 4.6273
# Epoch 41/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6515 - val_loss: 4.6237
# Epoch 42/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6476 - val_loss: 4.6209
# Epoch 43/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6448 - val_loss: 4.6189
# Epoch 44/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6426 - val_loss: 4.6175
# Epoch 45/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6411 - val_loss: 4.6165
# Epoch 46/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6399 - val_loss: 4.6157
# Epoch 47/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6391 - val_loss: 4.6151
# Epoch 48/50
# 2/2 [==============================] - 0s 21ms/step - loss: 4.6385 - val_loss: 4.6145
# Epoch 49/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6379 - val_loss: 4.6140
# Epoch 50/50
# 2/2 [==============================] - 0s 20ms/step - loss: 4.6375 - val_loss: 4.6136

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 6/6 [==============================] - 0s 1000us/step
#        reconstruction_error  true_class
# count            192.000000  192.000000
# mean             302.040870    0.447917
# std              387.568805    0.498580
# min                4.393702    0.000000
# 25%                4.574646    0.000000
# 50%               87.122526    0.000000
# 75%              612.196467    1.000000
# max             2137.739255    1.000000

# %%
error_df.head()
# Out:
#       reconstruction_error  true_class
# 8426            805.449864           0
# 201               4.545417           1
# 8625            634.005706           0
# 8175            976.270845           0
# 423               6.587804           1

# %% [markdown]
# label이 1인 feature만 학습했기 때문에, Test 데이터에서 0에 대한 reconstruction_error값이 매우 높게 나오고 있다.

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 15

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Normal" if name == 1 else "Abnormal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     106.0
#            1       0.00      0.00      0.00      86.0
#
#     accuracy                           0.00     192.0
#    macro avg       0.00      0.00      0.00     192.0
# weighted avg       0.00      0.00      0.00     192.0
